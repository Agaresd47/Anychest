# %%
transform_combinations = [
    # 1. Geometric + Intensity
    {   "zoom_and_crop": [1.05],
        "rotate_image": [-10],
        "axis_aligned_flip": ["horizontal"],
        
        "adjust_brightness": [5],
        "adjust_contrast": [1.1]
    },

    # 2. Geometric + Noise
    {   "zoom_and_crop": [0.95],
        "rotate_image": [15],
        "axis_aligned_flip": ["vertical"],
        
        "add_gaussian_noise": [0, 0.2],
        "add_speckle_noise": [0.1]
    },

    # 3. Occlusions + Intensity
    {
        "random_occlusions": [2, (30, 30)],
        "adjust_brightness": [-7],
        "apply_gamma_adjustment": [0.9],
        "adjust_contrast": [0.85]
    },

    # 4. Blur + Intensity
    {
        "gaussian_blur": [2],
        "adjust_brightness": [10],
        "apply_gamma_adjustment": [1.2],
        "adjust_contrast": [0.9]
    },

    # 5. Geometric + Advanced Adjustments
    {   "zoom_and_crop": [1.1],
        "rotate_image": [-20],
        "axis_aligned_flip": ["horizontal"],
        
        "bias_field_simulation": [0.2],
        "boundary_smoothing": [3]
    },

    # 6. Occlusions + Noise
    {
        "random_occlusions": [3, (20, 20)],
        "add_gaussian_noise": [0, 0.1],
        "add_speckle_noise": [0.05],
        "adjust_brightness": [-5]
    },

    # 7. Noise + Blur
    {
        "add_gaussian_noise": [0, 0.3],
        "add_speckle_noise": [0.2],
        "gaussian_blur": [3],
        "apply_gamma_adjustment": [1.1]
    },

    # 8. Advanced Adjustments
    {
        "bias_field_simulation": [0.3],
        "boundary_smoothing": [5],
        "histogram_equalization": [True],
        "adjust_brightness": [-8]
    },

    # 9. Geometric + Occlusions
    {   "zoom_and_crop": [1.05],
        "rotate_image": [10],
        "axis_aligned_flip": ["vertical"],
        "random_occlusions": [1, (40, 40)],
        
    },

    # 10. Mixed Transformations
    {   "zoom_and_crop": [0.9],
        "rotate_image": [-15],
        
        "add_gaussian_noise": [0, 0.2],
        "gaussian_blur": [1],
        "adjust_contrast": [1.2]
    }
]

# %%
parameter_ranges = {
    # Geometric Transformations
    "rotate_image": (-20, 20),  # Rotation: Range -20° to +20° (evenly sampled)
    "zoom_and_crop": (0.9, 1.1),  # Zoom: Range 0.9x to 1.1x (evenly sampled)
    # Random Occlusions under Geometric trans
    "random_occlusions": {  # Random Occlusions (only size matters here)
        "num_occlusions": (0.00001 , 6),  # number of occlusions:assign whole number
        "size": (20, 40),  # Size: Range 20x20 to 40x40 pixels (evenly sampled)
    },

    # Intensity Transformations
    "adjust_brightness": (-10, 10),  # Brightness: Range -10 to +10 (evenly sampled)
    "adjust_contrast": (0.8, 1.2),  # Contrast: Range 0.8 to 1.2 (evenly sampled)
    "apply_gamma_adjustment": (0.8, 1.2),  # Gamma Correction: Range 0.8 to 1.2 (evenly sampled)

    # Noise Injection
    "add_gaussian_noise": (0.1, 0.3),  # Gaussian Noise: std range 0.1 to 0.3 (evenly sampled)
    "add_speckle_noise": (0.05, 0.2),  # Speckle Noise: Variance range 0.05 to 0.2 (evenly sampled)

    # Blurring/Sharpening
    "gaussian_blur": (1, 3),  # Gaussian Blur: Sigma range 1 to 3 (evenly sampled)
    "gaussian_sharpening": (0.5, 1.5),  # Gaussian Sharpening: Amount range 0.5 to 1.5 (evenly sampled)

    

    # Advanced Adjustments
    "bias_field_simulation": (0.1, 0.3),  # Bias Field Simulation: Max bias 0.1 to 0.3 (evenly sampled)
    "boundary_smoothing": (0.0001, 5),  # Boundary Smoothing: Kernel size 1 to 5 (whole numbers)
}

# %%
def count_transformation_methods(transform_combinations):
    """
    Counts the occurrences of each transformation method in a set of transformation combinations.

    Args:
        transform_combinations (list): A list of dictionaries where each dictionary defines a transformation combination.

    Returns:
        list: A list of tuples where each tuple contains a transformation method and its total count.
    """
    from collections import Counter

    method_counter = Counter()

    for combination in transform_combinations:
        for method in combination.keys():
            method_counter[method] += 1

    # Convert to a list of tuples (method, count)
    method_counts = list(method_counter.items())

    return method_counts



method_counts = count_transformation_methods(transform_combinations)
print(method_counts)
# Out:
# [('zoom_and_crop', 5), ('rotate_image', 5), ('axis_aligned_flip', 4), ('adjust_brightness', 5), ('adjust_contrast', 4), ('add_gaussian_noise', 4), ('add_speckle_noise', 3), ('random_occlusions', 3), ('apply_gamma_adjustment', 3), ('gaussian_blur', 3), ('bias_field_simulation', 2), ('boundary_smoothing', 2), ('histogram_equalization', 1)]

# %%
def calculate_intervals(method_counts, total_samples, parameter_ranges, special_list=None):
    """
    Calculate interval sizes for each transformation method based on their ranges and total usage.

    Args:
        method_counts (list): A list of tuples where each tuple contains a transformation method and its count.
        total_samples (int): Total number of samples to process.
        parameter_ranges (dict): A dictionary of parameter ranges for each transformation method.

    Returns:
        dict: A dictionary containing interval sizes for each method.
    """
    
    if special_list is None:
        special_list = []
        
    overlap = set(parameter_ranges.keys()).intersection(set(special_list))
    if overlap:
        raise ValueError(f"The following methods appear in both parameter_ranges and special_list: {overlap}")

    # Ensure all methods in method_counts are covered in parameter_ranges or special_list
    all_methods = set([method for method, _ in method_counts])
    covered_methods = set(parameter_ranges.keys()).union(set(special_list))

    if not all_methods.issubset(covered_methods):
        missing_methods = all_methods - covered_methods
        raise ValueError(f"The following methods are missing from parameter_ranges or special_list: {missing_methods}")
    
    
    intervals = {}

    for method, count in method_counts:
        total_appearance_count = count * total_samples * 2  # Each method applied twice per sample

        if method in parameter_ranges:
            # Handle evenly sampled ranges
            if isinstance(parameter_ranges[method], tuple):
                range_start, range_end = parameter_ranges[method]
                interval_size = (range_end - range_start) / total_appearance_count
                intervals[method] = interval_size

            # Handle special cases (like random_occlusions)
            elif isinstance(parameter_ranges[method], dict):
                special_intervals = {}
                for sub_param, (start, end) in parameter_ranges[method].items():
                    interval_size = (end - start) / total_appearance_count
                    special_intervals[sub_param] = interval_size
                intervals[method] = special_intervals

    return intervals

total_samples = 300

# Example usage
special_list = [ "axis_aligned_flip", "histogram_equalization"]
intervals = calculate_intervals(method_counts, total_samples, parameter_ranges, special_list)
print(intervals)
# Out:
# {'zoom_and_crop': 6.666666666666668e-05, 'rotate_image': 0.013333333333333334, 'adjust_brightness': 0.006666666666666667, 'adjust_contrast': 0.00016666666666666663, 'add_gaussian_noise': 8.333333333333333e-05, 'add_speckle_noise': 8.333333333333334e-05, 'random_occlusions': {'num_occlusions': 0.003333327777777778, 'size': 0.011111111111111112}, 'apply_gamma_adjustment': 0.00022222222222222218, 'gaussian_blur': 0.0011111111111111111, 'bias_field_simulation': 0.00016666666666666666, 'boundary_smoothing': 0.004166583333333334}

# %%
import math
print(math.ceil(0.001))
# Out:
# 1

# %%
import math
import random
def special_list_function(method, params, order, parameter_ranges, intervals, method_counts):
    """
    Handles special cases for transformation methods.
    Args:
        method (str): The method name.
        params (any): The parameters for the method.
        order (int): The current order number.
        parameter_ranges (dict): Parameter ranges for methods.
        intervals (dict): Calculated intervals for each transformation method.
        method_counts (dict): Count of occurrences for each method.
    Returns:
        any: Updated parameters for the method.
    """
    if method == "random_occlusions":
        # Special handling for random_occlusions using intervals and lower parameter ranges
        num_occlusions = float(parameter_ranges[method]["num_occlusions"][0]) + float(((order - 1) * intervals[method]["num_occlusions"] / method_counts[method]))
        size_variation = random.uniform(1, 5)  # Add random variation factor between 1 and 5
        size_variation_sec = random.uniform(1, 3)  # Add random variation factor between 1 and 5
        size = (
            parameter_ranges[method]["size"][0] + ((order - 1) * intervals[method]["size"] / method_counts[method]) * size_variation,
            parameter_ranges[method]["size"][0] + ((order - 1) * intervals[method]["size"] / method_counts[method]) * size_variation_sec
        )
        return [math.ceil(num_occlusions), size]
    elif method == "axis_aligned_flip":
        # Alternate between "vertical" and "horizontal" based on the order
        return ["vertical"] if order % 2 == 1 else ["horizontal"]
    elif method == "histogram_equalization":
        # Always return True for histogram_equalization
        return True
    return params

def process_transformations(order, transform_combinations, intervals, special_list, parameter_ranges, method_counts):
    """
    Process a single image-mask pair with specified transformation combinations and intervals.

    Args:
        order (int): The order number of the transformation (e.g., 1 to total_samples*2).
        transform_combinations (list): List of transformation combination dictionaries.
        intervals (dict): Calculated intervals for each transformation method.
        special_list (list): List of special methods that require custom handling.
        parameter_ranges (dict): Parameter ranges for methods.
        method_counts (dict): Count of occurrences for each method.

    Returns:
        list: Modified transform_combinations with updated parameters.
    """
    # Ensure method_counts is always a dictionary
    if isinstance(method_counts, list):
        method_counts = dict(method_counts)
        
        
    updated_combinations = []
    current_method_orders = {method: 0 for method in method_counts}
    
    

    for combination in transform_combinations:
        updated_combination = {}
        for method, params in combination.items():
            current_order = (order - 1) * method_counts[method] + current_method_orders[method] + 1
            if method in special_list:
                # Call special_list_function for special handling
                updated_combination[method] = special_list_function(method, params, current_order, parameter_ranges, intervals, method_counts)
            elif method in intervals:
                # Regular calculation process with base as lower parameter range
                if isinstance(intervals[method], dict):
                    updated_combination[method] = {}
                    for sub_param in intervals[method]:
                        try:
                            # Check if params[sub_param] exists and is a list
                            if sub_param not in params or not isinstance(params[sub_param], list):
                                raise ValueError(f"Parameter '{sub_param}' for method '{method}' must be a list.")
                            updated_combination[method][sub_param] = parameter_ranges[method][sub_param][0] + ((current_order - 1) * intervals[method][sub_param] / method_counts[method])
                        except Exception as e:
                            raise ValueError(f"Error with method '{method}' and parameter '{sub_param}': {e}")
                else:
                    updated_combination[method] = parameter_ranges[method][0] + ((current_order - 1) * intervals[method] / method_counts[method])
            else:
                raise ValueError(f"Method {method} is not recognized in intervals or special_list.")

            current_method_orders[method] = current_method_orders[method] + 1

        updated_combinations.append(updated_combination)

    return updated_combinations

special_list.append("random_occlusions")
updated_combinations = process_transformations(
    1, transform_combinations, intervals, special_list, parameter_ranges, method_counts
)

# %%
random.uniform(1, 5)
# Out:
# 2.5885965549332948

# %%
def print_updated_combinations(updated_combinations):
    """
    Helper function to print updated combinations in a readable format.

    Args:
        updated_combinations (list): List of updated transformation combinations.
    """
    print("Updated Combinations:")
    for idx, combination in enumerate(updated_combinations, start=1):
        print(f"Combination {idx}:")
        for method, params in combination.items():
            print(f"  {method}: {params}")
    print()
    
print_updated_combinations(updated_combinations)
# Out:
# Updated Combinations:
# Combination 1:
#   zoom_and_crop: 0.9
#   rotate_image: -20.0
#   axis_aligned_flip: ['vertical']
#   adjust_brightness: -10.0
#   adjust_contrast: 0.8
# Combination 2:
#   zoom_and_crop: 0.9000133333333333
#   rotate_image: -19.997333333333334
#   axis_aligned_flip: ['horizontal']
#   add_gaussian_noise: 0.1
#   add_speckle_noise: 0.05
# Combination 3:
#   random_occlusions: [1, (20.0, 20.0)]
#   adjust_brightness: -9.998666666666667
#   apply_gamma_adjustment: 0.8
#   adjust_contrast: 0.8000416666666668
# Combination 4:
#   gaussian_blur: 1.0
#   adjust_brightness: -9.997333333333334
#   apply_gamma_adjustment: 0.8000740740740742
#   adjust_contrast: 0.8000833333333334
# Combination 5:
#   zoom_and_crop: 0.9000266666666666
#   rotate_image: -19.994666666666667
#   axis_aligned_flip: ['vertical']
#   bias_field_simulation: 0.1
#   boundary_smoothing: 0.0001
# Combination 6:
#   random_occlusions: [1, (20.006762693994325, 20.010872881024625)]
#   add_gaussian_noise: 0.10002083333333334
#   add_speckle_noise: 0.05002777777777778
#   adjust_brightness: -9.996
# Combination 7:
#   add_gaussian_noise: 0.10004166666666667
#   add_speckle_noise: 0.05005555555555556
#   gaussian_blur: 1.0003703703703704
#   apply_gamma_adjustment: 0.8001481481481482
# Combination 8:
#   bias_field_simulation: 0.10008333333333334
#   boundary_smoothing: 0.0021832916666666667
#   histogram_equalization: True
#   adjust_brightness: -9.994666666666667
# Combination 9:
#   zoom_and_crop: 0.9000400000000001
#   rotate_image: -19.992
#   axis_aligned_flip: ['horizontal']
#   random_occlusions: [1, (20.018833100603793, 20.021280708176164)]
# Combination 10:
#   zoom_and_crop: 0.9000533333333334
#   rotate_image: -19.989333333333335
#   add_gaussian_noise: 0.1000625
#   gaussian_blur: 1.0007407407407407
#   adjust_contrast: 0.8001250000000001

# %%
import os

def explore_folder_mismatch(img_folder, mask_folder):
    """
    Compares the contents of two folders and identifies mismatched files.

    Args:
        img_folder (str): Path to the folder containing images.
        mask_folder (str): Path to the folder containing masks.

    Returns:
        None
    """
    # List files in both folders
    img_files = sorted(os.listdir(img_folder))
    mask_files = sorted(os.listdir(mask_folder))

    # Convert file lists to sets
    img_set = set(img_files)
    mask_set = set(mask_files)

    # Identify mismatches
    only_in_img = img_set - mask_set
    only_in_mask = mask_set - img_set
    common_files = img_set & mask_set

    # Print mismatched files
    print("Files only in image folder:")
    for file in only_in_img:
        print(f"  {file}")
    print("\nFiles only in mask folder:")
    for file in only_in_mask:
        print(f"  {file}")
    print("\nCommon files:")
    for file in common_files:
        print(f"  {file}")

    # Check filename patterns (e.g., nnU-Net naming convention)
    print("\nChecking filename patterns:")
    img_pattern_mismatches = [file for file in img_files if "_0000" not in file]
    if img_pattern_mismatches:
        print("  Files in image folder without '_0000':")
        for file in img_pattern_mismatches:
            print(f"    {file}")

    mask_pattern_mismatches = [file for file in mask_files if "_0000" not in file]
    if mask_pattern_mismatches:
        print("  Files in mask folder without '_0000':")
        for file in mask_pattern_mismatches:
            print(f"    {file}")

    # Summary
    print("\nSummary:")
    print(f"Total files in image folder: {len(img_files)}")
    print(f"Total files in mask folder: {len(mask_files)}")
    print(f"Files only in image folder: {len(only_in_img)}")
    print(f"Files only in mask folder: {len(only_in_mask)}")
    print(f"Common files: {len(common_files)}")

# Example Usage
img_folder = "/data/bruce/unet/Dataset002_AnychestTry/imagesTr"
mask_folder = "/data/bruce/unet/Dataset002_AnychestTry/labelsTr"
explore_folder_mismatch(img_folder, mask_folder)
# Out:
# Files only in image folder:
#   t_5074_a_1_0000.nii.gz
#   t_15131_a_1_0000.nii.gz
#   t_12717_a_1_0000.nii.gz
#   t_11026_a_1_0000.nii.gz
#   t_17959_a_1_0000.nii.gz
#   t_18730_a_1_0000.nii.gz
#   t_8222_a_1_0000.nii.gz
#   t_19245_a_1_0000.nii.gz
#   t_8458_a_1_0000.nii.gz
#   t_15629_a_1_0000.nii.gz
#   t_11303_a_1_0000.nii.gz
#   t_6132_a_1_0000.nii.gz
#   t_16384_a_1_0000.nii.gz
#   t_9941_a_1_0000.nii.gz
#   t_11066_a_1_0000.nii.gz
#   t_9386_a_1_0000.nii.gz
#   t_8837_a_1_0000.nii.gz
#   t_8565_a_1_0000.nii.gz
#   t_12387_a_1_0000.nii.gz
#   t_916_a_1_0000.nii.gz
#   t_1680_a_1_0000.nii.gz
#   t_18477_a_1_0000.nii.gz
#   t_13888_a_1_0000.nii.gz
#   t_3710_a_1_0000.nii.gz
#   t_7220_a_1_0000.nii.gz
#   t_1270_a_1_0000.nii.gz
#   t_2620_a_1_0000.nii.gz
#   t_11476_a_1_0000.nii.gz
#   t_3138_a_1_0000.nii.gz
#   t_14376_a_2_0000.nii.gz
#   t_2275_a_1_0000.nii.gz
#   t_184_a_1_0000.nii.gz
#   t_6960_a_1_0000.nii.gz
#   t_11432_a_1_0000.nii.gz
#   t_17202_a_1_0000.nii.gz
#   t_12040_a_1_0000.nii.gz
#   t_12520_a_1_0000.nii.gz
#   t_13720_a_1_0000.nii.gz
#   t_18983_a_1_0000.nii.gz
#   t_2262_a_1_0000.nii.gz
#   t_3038_b_1_0000.nii.gz
#   t_3799_a_1_0000.nii.gz
#   t_8093_a_1_0000.nii.gz
#   t_8030_a_1_0000.nii.gz
#   t_13639_a_1_0000.nii.gz
#   t_14281_a_1_0000.nii.gz
#   t_14891_a_1_0000.nii.gz
#   t_15157_a_1_0000.nii.gz
#   t_15410_a_1_0000.nii.gz
#   t_17631_a_1_0000.nii.gz
#   t_3787_a_1_0000.nii.gz
#   t_19093_b_1_0000.nii.gz
#   t_4051_a_1_0000.nii.gz
#   t_7223_a_1_0000.nii.gz
#   t_1205_a_1_0000.nii.gz
#   t_17315_a_1_0000.nii.gz
#   t_13118_a_1_0000.nii.gz
#   t_19742_a_1_0000.nii.gz
#   t_11388_a_1_0000.nii.gz
#   t_3018_a_1_0000.nii.gz
#   t_19797_a_1_0000.nii.gz
#   t_9015_a_1_0000.nii.gz
#   t_13714_a_1_0000.nii.gz
#   t_17592_a_1_0000.nii.gz
#   t_237_b_1_0000.nii.gz
#   t_18997_a_1_0000.nii.gz
#   t_4193_a_1_0000.nii.gz
#   t_966_a_1_0000.nii.gz
#   t_18163_a_1_0000.nii.gz
#   t_18684_a_1_0000.nii.gz
#   t_1018_a_2_0000.nii.gz
#   t_1734_a_1_0000.nii.gz
#   t_14990_a_1_0000.nii.gz
#   t_15078_a_1_0000.nii.gz
#   t_3092_a_1_0000.nii.gz
#   t_8890_a_1_0000.nii.gz
#   t_14401_a_1_0000.nii.gz
#   t_1753_a_1_0000.nii.gz
#   t_13304_a_1_0000.nii.gz
#   t_512_a_1_0000.nii.gz
#   t_1086_a_1_0000.nii.gz
#   t_14489_a_1_0000.nii.gz
#   t_18821_a_1_0000.nii.gz
#   t_14796_a_1_0000.nii.gz
#   t_10062_a_1_0000.nii.gz
#   t_16761_a_1_0000.nii.gz
#   t_19205_a_1_0000.nii.gz
#   t_7845_b_1_0000.nii.gz
#   t_7804_a_1_0000.nii.gz
#   t_19705_a_1_0000.nii.gz
#   t_12627_a_1_0000.nii.gz
#   t_6274_a_1_0000.nii.gz
#   t_17708_a_1_0000.nii.gz
#   t_4433_a_1_0000.nii.gz
#   t_2928_a_1_0000.nii.gz
#   t_7265_a_1_0000.nii.gz
#   t_8554_a_1_0000.nii.gz
#   t_18167_a_1_0000.nii.gz
#   t_8300_a_1_0000.nii.gz
#   t_1792_a_1_0000.nii.gz
#   t_2224_a_1_0000.nii.gz
#   t_17293_a_1_0000.nii.gz
#   t_19524_a_1_0000.nii.gz
#   t_8844_a_1_0000.nii.gz
#   t_924_a_1_0000.nii.gz
#   t_13970_a_1_0000.nii.gz
#   t_9484_a_1_0000.nii.gz
#   t_2574_b_1_0000.nii.gz
#   t_6669_a_1_0000.nii.gz
#   t_10592_a_1_0000.nii.gz
#   t_1120_a_1_0000.nii.gz
#   t_1942_a_1_0000.nii.gz
#   t_11952_a_1_0000.nii.gz
#   t_18187_a_1_0000.nii.gz
#   t_17324_a_1_0000.nii.gz
#   t_15065_a_1_0000.nii.gz
#   t_12631_a_1_0000.nii.gz
#   t_2408_a_1_0000.nii.gz
#   t_2689_a_1_0000.nii.gz
#   t_11816_a_1_0000.nii.gz
#   t_13077_a_1_0000.nii.gz
#   t_7259_a_1_0000.nii.gz
#   t_1542_a_1_0000.nii.gz
#   t_501_a_1_0000.nii.gz
#   t_13620_a_1_0000.nii.gz
#   t_1700_a_1_0000.nii.gz
#   t_9763_a_1_0000.nii.gz
#   t_17426_a_1_0000.nii.gz
#   t_18353_a_1_0000.nii.gz
#   t_13692_a_1_0000.nii.gz
#   t_7262_a_1_0000.nii.gz
#   t_19529_a_1_0000.nii.gz
#   t_5266_a_1_0000.nii.gz
#   t_11010_a_1_0000.nii.gz
#   t_1706_d_1_0000.nii.gz
#   t_2478_a_1_0000.nii.gz
#   t_7328_a_1_0000.nii.gz
#   t_16831_a_1_0000.nii.gz
#   t_7912_a_1_0000.nii.gz
#   t_5000_b_1_0000.nii.gz
#   t_12077_a_1_0000.nii.gz
#   t_2991_a_1_0000.nii.gz
#   t_7293_a_1_0000.nii.gz
#   t_7974_a_1_0000.nii.gz
#   t_7368_a_1_0000.nii.gz
#   t_19956_a_1_0000.nii.gz
#   t_7346_a_1_0000.nii.gz
#   t_15292_a_1_0000.nii.gz
#   t_16124_a_1_0000.nii.gz
#   t_14832_a_1_0000.nii.gz
#   t_17197_a_1_0000.nii.gz
#   t_11551_a_1_0000.nii.gz
#   t_7061_b_1_0000.nii.gz
#   t_7815_a_1_0000.nii.gz
#   t_18978_a_1_0000.nii.gz
#   t_19852_a_1_0000.nii.gz
#   t_1054_a_1_0000.nii.gz
#   t_4592_a_1_0000.nii.gz
#   t_11469_a_1_0000.nii.gz
#   t_15274_a_1_0000.nii.gz
#   t_790_a_1_0000.nii.gz
#   t_13375_a_1_0000.nii.gz
#   t_3144_a_1_0000.nii.gz
#   t_13983_a_1_0000.nii.gz
#   t_11421_a_1_0000.nii.gz
#   t_7650_a_1_0000.nii.gz
#   t_9158_a_1_0000.nii.gz
#   t_16666_a_1_0000.nii.gz
#   t_15467_a_1_0000.nii.gz
#   t_2315_a_1_0000.nii.gz
#   t_5989_a_1_0000.nii.gz
#   t_9507_a_1_0000.nii.gz
#   t_440_b_1_0000.nii.gz
#   t_8785_a_1_0000.nii.gz
#   t_2167_a_1_0000.nii.gz
#   t_4988_a_1_0000.nii.gz
#   t_8270_a_1_0000.nii.gz
#   t_8556_a_1_0000.nii.gz
#   t_11047_a_1_0000.nii.gz
#   t_12049_a_1_0000.nii.gz
#   t_3737_a_1_0000.nii.gz
#   t_3912_a_1_0000.nii.gz
#   t_4522_a_1_0000.nii.gz
#   t_7970_a_1_0000.nii.gz
#   t_2987_a_1_0000.nii.gz
#   t_6359_a_1_0000.nii.gz
#   t_4377_b_1_0000.nii.gz
#   t_5754_a_1_0000.nii.gz
#   t_13914_a_1_0000.nii.gz
#   t_2526_a_1_0000.nii.gz
#   t_4023_c_1_0000.nii.gz
#   t_9041_a_1_0000.nii.gz
#   t_14574_a_1_0000.nii.gz
#   t_15918_a_1_0000.nii.gz
#   t_4379_a_1_0000.nii.gz
#   t_7530_a_1_0000.nii.gz
#   t_4544_a_1_0000.nii.gz
#   t_8323_a_1_0000.nii.gz
#   t_511_a_1_0000.nii.gz
#   t_9060_a_1_0000.nii.gz
#   t_9702_a_1_0000.nii.gz
#   t_18132_a_1_0000.nii.gz
#   t_4029_a_1_0000.nii.gz
#   t_5417_a_2_0000.nii.gz
#   t_10177_a_1_0000.nii.gz
#   t_10860_a_1_0000.nii.gz
#   t_14760_a_1_0000.nii.gz
#   t_14763_a_1_0000.nii.gz
#   t_19909_a_1_0000.nii.gz
#   t_19391_a_1_0000.nii.gz
#   t_5682_a_1_0000.nii.gz
#   t_10627_a_1_0000.nii.gz
#   t_2025_a_1_0000.nii.gz
#   t_12741_a_1_0000.nii.gz
#   t_5816_a_1_0000.nii.gz
#   t_2529_a_1_0000.nii.gz
#   t_13244_a_1_0000.nii.gz
#   t_5030_a_1_0000.nii.gz
#   t_10596_a_1_0000.nii.gz
#   t_18600_a_1_0000.nii.gz
#   t_9055_a_1_0000.nii.gz
#   t_11602_a_1_0000.nii.gz
#   t_18153_a_1_0000.nii.gz
#   t_5992_a_1_0000.nii.gz
#   t_3723_a_1_0000.nii.gz
#   t_1987_b_1_0000.nii.gz
#   t_6487_a_1_0000.nii.gz
#   t_4306_a_1_0000.nii.gz
#   t_6130_b_1_0000.nii.gz
#   t_15346_a_1_0000.nii.gz
#   t_7883_a_1_0000.nii.gz
#   t_10311_a_1_0000.nii.gz
#   t_11658_a_1_0000.nii.gz
#   t_19627_a_1_0000.nii.gz
#   t_2383_a_1_0000.nii.gz
#   t_19999_a_1_0000.nii.gz
#   t_9572_a_1_0000.nii.gz
#   t_11609_a_1_0000.nii.gz
#   t_16132_a_1_0000.nii.gz
#   t_11186_b_1_0000.nii.gz
#   t_3772_a_1_0000.nii.gz
#   t_5359_a_1_0000.nii.gz
#   t_14214_c_1_0000.nii.gz
#   t_10845_a_1_0000.nii.gz
#   t_17553_a_1_0000.nii.gz
#   t_3928_a_1_0000.nii.gz
#   t_5495_a_1_0000.nii.gz
#   t_5257_a_1_0000.nii.gz
#   t_18612_a_1_0000.nii.gz
#   t_14571_a_1_0000.nii.gz
#   t_6443_a_1_0000.nii.gz
#   t_18135_a_1_0000.nii.gz
#   t_11946_a_1_0000.nii.gz
#   t_11126_a_1_0000.nii.gz
#   t_842_a_1_0000.nii.gz
#   t_3145_a_1_0000.nii.gz
#   t_3080_a_1_0000.nii.gz
#   t_9714_a_1_0000.nii.gz
#   t_15257_a_1_0000.nii.gz
#   t_13147_a_1_0000.nii.gz
#   t_9820_a_1_0000.nii.gz
#   t_2319_a_1_0000.nii.gz
#   t_7329_a_1_0000.nii.gz
#   t_11273_a_1_0000.nii.gz
#   t_18098_a_1_0000.nii.gz
#   t_727_a_1_0000.nii.gz
#   t_8912_a_1_0000.nii.gz
#   t_5261_a_1_0000.nii.gz
#   t_488_a_1_0000.nii.gz
#   t_4875_a_1_0000.nii.gz
#   t_19919_a_1_0000.nii.gz
#   t_8420_d_1_0000.nii.gz
#   t_19962_a_1_0000.nii.gz
#   t_712_a_1_0000.nii.gz
#   t_10208_a_1_0000.nii.gz
#   t_6175_a_1_0000.nii.gz
#   t_9245_a_1_0000.nii.gz
#   t_8018_a_1_0000.nii.gz
#   t_7673_a_1_0000.nii.gz
#   t_14323_a_1_0000.nii.gz
#   t_14979_a_1_0000.nii.gz
#   t_16200_a_1_0000.nii.gz
#   t_9329_a_1_0000.nii.gz
#   t_11652_a_1_0000.nii.gz
#   t_3779_a_1_0000.nii.gz
#   t_14369_a_1_0000.nii.gz
#   t_19599_a_1_0000.nii.gz
#   t_1522_a_1_0000.nii.gz
#   t_838_a_1_0000.nii.gz
#   t_11485_b_1_0000.nii.gz
#   t_18798_a_1_0000.nii.gz
#   t_8756_a_1_0000.nii.gz
#   t_14632_a_1_0000.nii.gz
#   t_19132_a_1_0000.nii.gz
#   t_17421_a_1_0000.nii.gz
#   t_8549_c_1_0000.nii.gz
#   t_4143_a_1_0000.nii.gz
#   t_4286_a_1_0000.nii.gz
#   t_17778_a_1_0000.nii.gz
#   t_15632_a_1_0000.nii.gz
#   t_16525_a_1_0000.nii.gz
#   t_16622_a_1_0000.nii.gz
#   t_7644_a_1_0000.nii.gz
#   t_15502_a_1_0000.nii.gz
#   t_11956_a_1_0000.nii.gz
#   t_4489_a_1_0000.nii.gz
#   t_17813_a_1_0000.nii.gz
#   t_15488_a_1_0000.nii.gz
#   t_5817_b_1_0000.nii.gz
#   t_18636_a_1_0000.nii.gz
#   t_10987_a_1_0000.nii.gz
#   t_18486_a_1_0000.nii.gz
#   t_17874_a_1_0000.nii.gz
#   t_6375_a_1_0000.nii.gz
#   t_18757_a_1_0000.nii.gz
#   t_16235_a_1_0000.nii.gz
#   t_14746_a_1_0000.nii.gz
#   t_8392_a_1_0000.nii.gz
#   t_7085_a_1_0000.nii.gz
#   t_15203_a_1_0000.nii.gz
#   t_10782_a_1_0000.nii.gz
#   t_174_a_1_0000.nii.gz
#   t_2188_a_1_0000.nii.gz
#   t_8097_a_2_0000.nii.gz
#   t_13892_a_1_0000.nii.gz
#   t_14987_a_1_0000.nii.gz
#   t_9559_a_1_0000.nii.gz
#   t_350_a_1_0000.nii.gz
#   t_10216_a_1_0000.nii.gz
#   t_8464_a_1_0000.nii.gz
#   t_641_a_1_0000.nii.gz
#   t_754_a_1_0000.nii.gz
#   t_8871_a_1_0000.nii.gz
#   t_17615_a_1_0000.nii.gz
#   t_19317_a_1_0000.nii.gz
#   t_19283_a_1_0000.nii.gz
#   t_19166_a_1_0000.nii.gz
#   t_11132_a_1_0000.nii.gz
#   t_12146_a_1_0000.nii.gz
#   t_16718_a_1_0000.nii.gz
#   t_1385_a_1_0000.nii.gz
#   t_11805_a_1_0000.nii.gz
#   t_18587_a_1_0000.nii.gz
#   t_6581_a_1_0000.nii.gz
#   t_2306_a_1_0000.nii.gz
#   t_12361_a_1_0000.nii.gz
#   t_2296_a_1_0000.nii.gz
#   t_18988_a_1_0000.nii.gz
#   t_10319_a_1_0000.nii.gz
#   t_14142_a_1_0000.nii.gz
#   t_7602_a_1_0000.nii.gz
#   t_4885_a_1_0000.nii.gz
#   t_1267_a_1_0000.nii.gz
#   t_1805_a_1_0000.nii.gz
#   t_15857_a_1_0000.nii.gz
#   t_19915_a_1_0000.nii.gz
#   t_11453_a_1_0000.nii.gz
#   t_4603_a_1_0000.nii.gz
#   t_892_a_1_0000.nii.gz
#   t_1871_a_1_0000.nii.gz
#   t_560_a_1_0000.nii.gz
#   t_16741_a_1_0000.nii.gz
#   t_10214_a_1_0000.nii.gz
#   t_9184_a_1_0000.nii.gz
#   t_13958_a_1_0000.nii.gz
#   t_2898_a_1_0000.nii.gz
#   t_7054_a_1_0000.nii.gz
#   t_9630_a_1_0000.nii.gz
#   t_18027_a_1_0000.nii.gz
#   t_7157_a_1_0000.nii.gz
#   t_6328_a_1_0000.nii.gz
#   t_11960_a_1_0000.nii.gz
#   t_13749_a_1_0000.nii.gz
#   t_18242_a_1_0000.nii.gz
#   t_2704_a_1_0000.nii.gz
#   t_4467_a_1_0000.nii.gz
#   t_11850_a_1_0000.nii.gz
#   t_16949_a_1_0000.nii.gz
#   t_4786_a_1_0000.nii.gz
#   t_7481_a_1_0000.nii.gz
#   t_10026_a_1_0000.nii.gz
#   t_1378_a_1_0000.nii.gz
#   t_4504_b_1_0000.nii.gz
#   t_16354_a_1_0000.nii.gz
#   t_5885_a_1_0000.nii.gz
#   t_19279_c_1_0000.nii.gz
#   t_6688_b_1_0000.nii.gz
#   t_9888_a_1_0000.nii.gz
#   t_1214_a_1_0000.nii.gz
#   t_18428_a_1_0000.nii.gz
#   t_8779_a_1_0000.nii.gz
#   t_10981_b_1_0000.nii.gz
#   t_17562_a_1_0000.nii.gz
#   t_621_a_1_0000.nii.gz
#   t_16825_a_1_0000.nii.gz
#   t_9059_a_1_0000.nii.gz
#   t_15799_a_1_0000.nii.gz
#   t_8886_a_1_0000.nii.gz
#   t_13599_a_1_0000.nii.gz
#   t_15965_a_1_0000.nii.gz
#   t_10983_a_1_0000.nii.gz
#   t_1440_a_1_0000.nii.gz
#   t_454_a_1_0000.nii.gz
#   t_3003_a_1_0000.nii.gz
#   t_860_a_1_0000.nii.gz
#   t_19191_b_1_0000.nii.gz
#   t_12127_a_1_0000.nii.gz
#   t_277_a_1_0000.nii.gz
#   t_4671_a_1_0000.nii.gz
#   t_15494_a_1_0000.nii.gz
#   t_7002_a_1_0000.nii.gz
#   t_131_a_1_0000.nii.gz
#   t_10310_a_1_0000.nii.gz
#   t_1958_a_1_0000.nii.gz
#   t_10494_a_1_0000.nii.gz
#   t_3052_a_1_0000.nii.gz
#   t_13113_a_1_0000.nii.gz
#   t_18196_a_1_0000.nii.gz
#   t_2888_a_1_0000.nii.gz
#   t_2936_a_1_0000.nii.gz
#   t_19578_a_1_0000.nii.gz
#   t_2160_a_1_0000.nii.gz
#   t_11281_a_1_0000.nii.gz
#   t_15248_a_1_0000.nii.gz
#   t_8974_a_1_0000.nii.gz
#   t_13178_a_1_0000.nii.gz
#   t_491_a_1_0000.nii.gz
#   t_6138_a_1_0000.nii.gz
#   t_15645_a_1_0000.nii.gz
#   t_662_c_1_0000.nii.gz
#   t_2541_b_1_0000.nii.gz
#   t_992_a_1_0000.nii.gz
#   t_3918_a_1_0000.nii.gz
#   t_11594_a_1_0000.nii.gz
#   t_12595_a_1_0000.nii.gz
#   t_15358_a_1_0000.nii.gz
#   t_13276_a_1_0000.nii.gz
#   t_742_a_1_0000.nii.gz
#   t_10572_a_1_0000.nii.gz
#   t_15940_b_1_0000.nii.gz
#   t_2481_a_1_0000.nii.gz
#   t_17998_a_1_0000.nii.gz
#   t_16155_a_1_0000.nii.gz
#   t_8601_a_1_0000.nii.gz
#   t_7117_a_1_0000.nii.gz
#   t_13380_a_1_0000.nii.gz
#   t_10663_a_1_0000.nii.gz
#   t_3173_b_1_0000.nii.gz
#   t_1464_a_1_0000.nii.gz
#   t_13301_b_1_0000.nii.gz
#   t_3769_a_1_0000.nii.gz
#   t_18616_a_1_0000.nii.gz
#   t_12489_a_1_0000.nii.gz
#   t_19781_a_1_0000.nii.gz
#   t_3565_a_1_0000.nii.gz
#   t_19772_a_1_0000.nii.gz
#   t_15430_a_1_0000.nii.gz
#   t_573_a_1_0000.nii.gz
#   t_19450_a_1_0000.nii.gz
#   t_11372_a_1_0000.nii.gz
#   t_10591_a_1_0000.nii.gz
#   t_1545_a_1_0000.nii.gz
#   t_11613_a_1_0000.nii.gz
#   t_11038_a_1_0000.nii.gz
#   t_7058_a_1_0000.nii.gz
#   t_14431_a_1_0000.nii.gz
#   t_14984_a_1_0000.nii.gz
#   t_6759_a_1_0000.nii.gz
#   t_7131_a_1_0000.nii.gz
#   t_50_a_1_0000.nii.gz
#   t_7236_a_1_0000.nii.gz
#   t_9131_a_1_0000.nii.gz
#   t_5618_a_1_0000.nii.gz
#   t_5725_a_1_0000.nii.gz
#   t_16088_a_1_0000.nii.gz
#   t_17268_a_1_0000.nii.gz
#   t_784_a_1_0000.nii.gz
#   t_3653_e_1_0000.nii.gz
#   t_5815_a_1_0000.nii.gz
#   t_6918_a_1_0000.nii.gz
#   t_19219_b_1_0000.nii.gz
#   t_16107_a_1_0000.nii.gz
#   t_7288_a_1_0000.nii.gz
#   t_10955_a_1_0000.nii.gz
#   t_14166_b_1_0000.nii.gz
#   t_11963_a_1_0000.nii.gz
#   t_8981_a_1_0000.nii.gz
#   t_10694_a_1_0000.nii.gz
#   t_6902_b_1_0000.nii.gz
#   t_13213_a_1_0000.nii.gz
#   t_17453_c_1_0000.nii.gz
#   t_3686_a_1_0000.nii.gz
#   t_807_a_1_0000.nii.gz
#   t_3641_a_1_0000.nii.gz
#   t_19539_a_1_0000.nii.gz
#   t_10803_a_1_0000.nii.gz
#   t_12912_a_1_0000.nii.gz
#   t_1437_b_1_0000.nii.gz
#   t_8101_b_1_0000.nii.gz
#   t_15240_a_1_0000.nii.gz
#   t_5507_b_1_0000.nii.gz
#   t_112_a_1_0000.nii.gz
#   t_16074_a_1_0000.nii.gz
#   t_14601_a_1_0000.nii.gz
#   t_18956_a_1_0000.nii.gz
#   t_4436_b_1_0000.nii.gz
#   t_13824_b_1_0000.nii.gz
#   t_16896_a_1_0000.nii.gz
#   t_6482_a_2_0000.nii.gz
#   t_12563_b_1_0000.nii.gz
#   t_288_a_1_0000.nii.gz
#   t_17328_a_1_0000.nii.gz
#   t_1935_a_1_0000.nii.gz
#   t_3143_a_1_0000.nii.gz
#   t_12551_a_1_0000.nii.gz
#   t_16790_a_1_0000.nii.gz
#   t_12572_a_1_0000.nii.gz
#   t_11095_a_1_0000.nii.gz
#   t_1395_a_1_0000.nii.gz
#   t_2488_a_1_0000.nii.gz
#   t_8418_a_1_0000.nii.gz
#   t_8898_a_1_0000.nii.gz
#   t_14876_a_1_0000.nii.gz
#   t_4772_a_1_0000.nii.gz
#   t_5190_a_1_0000.nii.gz
#   t_6283_a_1_0000.nii.gz
#   t_6636_a_1_0000.nii.gz
#   t_8330_a_1_0000.nii.gz
#   t_6672_a_1_0000.nii.gz
#   t_1901_a_1_0000.nii.gz
#   t_10152_a_1_0000.nii.gz
#   t_18253_a_1_0000.nii.gz
#   t_16547_a_1_0000.nii.gz
#   t_14169_a_1_0000.nii.gz
#   t_6440_a_1_0000.nii.gz
#   t_19875_b_1_0000.nii.gz
#   t_8278_a_1_0000.nii.gz
#   t_10936_a_1_0000.nii.gz
#   t_12000_a_1_0000.nii.gz
#   t_921_a_1_0000.nii.gz
#   t_17623_a_1_0000.nii.gz
#   t_7834_b_1_0000.nii.gz
#   t_16137_a_1_0000.nii.gz
#   t_17514_a_1_0000.nii.gz
#   t_7841_a_1_0000.nii.gz
#   t_1329_a_1_0000.nii.gz
#   t_15880_a_1_0000.nii.gz
#   t_10233_a_1_0000.nii.gz
#   t_13202_c_1_0000.nii.gz
#   t_12699_a_1_0000.nii.gz
#   t_15137_a_1_0000.nii.gz
#   t_17869_a_1_0000.nii.gz
#   t_13300_a_1_0000.nii.gz
#   t_7240_a_1_0000.nii.gz
#   t_5991_a_1_0000.nii.gz
#   t_18_a_1_0000.nii.gz
#   t_3603_a_1_0000.nii.gz
#   t_9616_a_1_0000.nii.gz
#   t_7756_a_1_0000.nii.gz
#   t_15508_a_1_0000.nii.gz
#   t_6898_a_1_0000.nii.gz
#   t_1322_a_1_0000.nii.gz
#   t_18341_a_1_0000.nii.gz
#   t_14648_a_1_0000.nii.gz
#   t_9346_a_1_0000.nii.gz
#   t_15047_a_1_0000.nii.gz
#   t_6797_a_1_0000.nii.gz
#   t_18839_a_1_0000.nii.gz
#   t_19274_a_1_0000.nii.gz
#   t_19817_a_1_0000.nii.gz
#   t_16652_a_1_0000.nii.gz
#   t_3880_a_1_0000.nii.gz
#   t_1229_a_1_0000.nii.gz
#   t_6690_a_1_0000.nii.gz
#   t_15038_a_1_0000.nii.gz
#   t_10296_b_1_0000.nii.gz
#   t_8474_a_1_0000.nii.gz
#   t_12952_a_1_0000.nii.gz
#   t_6072_a_1_0000.nii.gz
#   t_9972_a_1_0000.nii.gz
#   t_7667_a_1_0000.nii.gz
#   t_10393_a_1_0000.nii.gz
#   t_8342_a_1_0000.nii.gz
#   t_9193_a_1_0000.nii.gz
#   t_17148_a_1_0000.nii.gz
#   t_5395_a_1_0000.nii.gz
#   t_2990_a_1_0000.nii.gz
#   t_10271_a_1_0000.nii.gz
#   t_7692_a_1_0000.nii.gz
#   t_18840_b_1_0000.nii.gz
#   t_3436_a_1_0000.nii.gz
#   t_12372_a_1_0000.nii.gz
#   t_291_a_2_0000.nii.gz
#   t_12455_b_1_0000.nii.gz
#   t_8673_a_1_0000.nii.gz
#   t_17128_a_1_0000.nii.gz
#   t_11797_a_1_0000.nii.gz
#   t_7079_a_1_0000.nii.gz
#   t_16390_a_1_0000.nii.gz
#   t_6489_a_1_0000.nii.gz
#   t_18545_a_1_0000.nii.gz
#   t_4717_a_1_0000.nii.gz
#   t_10604_a_1_0000.nii.gz
#   t_14084_a_1_0000.nii.gz
#   t_84_a_1_0000.nii.gz
#   t_14519_a_1_0000.nii.gz
#   t_14926_a_1_0000.nii.gz
#   t_15010_a_1_0000.nii.gz
#   t_5235_a_1_0000.nii.gz
#   t_8340_a_1_0000.nii.gz
#   t_12711_a_1_0000.nii.gz
#   t_18640_a_1_0000.nii.gz
#   t_6835_b_1_0000.nii.gz
#   t_3403_a_1_0000.nii.gz
#   t_3210_a_1_0000.nii.gz
#   t_13036_a_1_0000.nii.gz
#   t_4514_b_1_0000.nii.gz
#   t_14728_a_1_0000.nii.gz
#   t_14947_c_1_0000.nii.gz
#   t_18154_a_1_0000.nii.gz
#   t_11344_b_1_0000.nii.gz
#   t_3088_a_1_0000.nii.gz
#   t_13942_a_1_0000.nii.gz
#   t_11260_a_2_0000.nii.gz
#   t_7604_a_1_0000.nii.gz
#   t_10549_a_1_0000.nii.gz
#   t_10671_a_1_0000.nii.gz
#   t_10473_b_1_0000.nii.gz
#   t_6047_b_1_0000.nii.gz
#   t_722_a_1_0000.nii.gz
#   t_11174_a_1_0000.nii.gz
#   t_14837_a_1_0000.nii.gz
#   t_14000_a_1_0000.nii.gz
#   t_14554_a_1_0000.nii.gz
#   t_8535_a_1_0000.nii.gz
#   t_18847_a_1_0000.nii.gz
#   t_17276_a_1_0000.nii.gz
#   t_4314_a_1_0000.nii.gz
#   t_6035_b_1_0000.nii.gz
#   t_11315_g_1_0000.nii.gz
#   t_8148_a_1_0000.nii.gz
#   t_10172_a_1_0000.nii.gz
#   t_19874_a_1_0000.nii.gz
#   t_2562_b_1_0000.nii.gz
#   t_5594_a_1_0000.nii.gz
#   t_66_a_1_0000.nii.gz
#   t_6932_a_1_0000.nii.gz
#   t_15895_a_1_0000.nii.gz
#   t_16606_a_1_0000.nii.gz
#   t_9521_a_1_0000.nii.gz
#   t_9687_a_1_0000.nii.gz
#   t_18746_a_1_0000.nii.gz
#   t_3796_a_1_0000.nii.gz
#   t_7487_a_1_0000.nii.gz
#   t_18055_a_1_0000.nii.gz
#   t_3268_a_1_0000.nii.gz
#   t_5437_a_1_0000.nii.gz
#   t_4944_a_1_0000.nii.gz
#   t_8112_a_1_0000.nii.gz
#   t_18754_a_1_0000.nii.gz
#   t_19482_a_1_0000.nii.gz
#   t_12786_a_1_0000.nii.gz
#   t_2187_a_1_0000.nii.gz
#   t_9756_a_1_0000.nii.gz
#   t_16058_a_1_0000.nii.gz
#   t_5597_a_1_0000.nii.gz
#   t_17999_c_1_0000.nii.gz
#   t_10438_a_1_0000.nii.gz
#   t_13151_a_1_0000.nii.gz
#   t_19401_a_1_0000.nii.gz
#   t_1600_a_1_0000.nii.gz
#   t_19761_a_1_0000.nii.gz
#   t_11669_a_1_0000.nii.gz
#   t_18693_a_1_0000.nii.gz
#   t_16070_a_1_0000.nii.gz
#   t_17237_a_1_0000.nii.gz
#   t_2823_a_1_0000.nii.gz
#   t_6380_a_1_0000.nii.gz
#   t_15156_a_1_0000.nii.gz
#   t_8132_a_1_0000.nii.gz
#   t_10908_a_1_0000.nii.gz
#   t_13711_a_1_0000.nii.gz
#   t_18753_a_1_0000.nii.gz
#   t_3522_a_1_0000.nii.gz
#   t_11880_c_1_0000.nii.gz
#   t_16951_b_1_0000.nii.gz
#   t_19173_a_1_0000.nii.gz
#   t_13339_a_1_0000.nii.gz
#   t_3286_a_1_0000.nii.gz
#   t_5356_a_1_0000.nii.gz
#   t_18791_a_1_0000.nii.gz
#   t_12849_a_1_0000.nii.gz
#   t_9106_a_1_0000.nii.gz
#   t_10533_a_1_0000.nii.gz
#   t_604_a_2_0000.nii.gz
#   t_10039_a_1_0000.nii.gz
#   t_16010_a_1_0000.nii.gz
#   t_1507_a_1_0000.nii.gz
#   t_6794_a_1_0000.nii.gz
#   t_745_a_1_0000.nii.gz
#   t_926_a_1_0000.nii.gz
#   t_6321_b_1_0000.nii.gz
#   t_6709_a_1_0000.nii.gz
#   t_1516_b_1_0000.nii.gz
#   t_19109_a_1_0000.nii.gz
#   t_16619_a_1_0000.nii.gz
#   t_17602_a_1_0000.nii.gz
#   t_16891_a_1_0000.nii.gz
#   t_8773_a_1_0000.nii.gz
#   t_11115_a_1_0000.nii.gz
#   t_15906_a_1_0000.nii.gz
#   t_6454_a_1_0000.nii.gz
#   t_2663_a_1_0000.nii.gz
#   t_8234_a_1_0000.nii.gz
#   t_15856_a_1_0000.nii.gz
#   t_16254_a_1_0000.nii.gz
#   t_14393_a_1_0000.nii.gz
#   t_8443_a_1_0000.nii.gz
#   t_4429_a_1_0000.nii.gz
#   t_9806_a_1_0000.nii.gz
#   t_15206_a_1_0000.nii.gz
#   t_17367_a_1_0000.nii.gz
#   t_18717_e_1_0000.nii.gz
#   t_3174_a_1_0000.nii.gz
#   t_5695_a_1_0000.nii.gz
#   t_9970_a_1_0000.nii.gz
#   t_5626_a_1_0000.nii.gz
#   t_10731_a_1_0000.nii.gz
#   t_12486_a_1_0000.nii.gz
#   t_11867_a_1_0000.nii.gz
#   t_3583_a_1_0000.nii.gz
#   t_12136_a_1_0000.nii.gz
#   t_5997_a_1_0000.nii.gz
#   t_7738_a_1_0000.nii.gz
#   t_19588_b_1_0000.nii.gz
#   t_18818_a_1_0000.nii.gz
#   t_2344_a_1_0000.nii.gz
#   t_7610_b_1_0000.nii.gz
#   t_8973_a_1_0000.nii.gz
#   t_8055_a_1_0000.nii.gz
#   t_17924_a_1_0000.nii.gz
#   t_12874_a_1_0000.nii.gz
#   t_17635_b_1_0000.nii.gz
#   t_13826_a_1_0000.nii.gz
#   t_7843_a_1_0000.nii.gz
#   t_1900_a_1_0000.nii.gz
#   t_10483_a_1_0000.nii.gz
#   t_6907_a_1_0000.nii.gz
#   t_4199_a_1_0000.nii.gz
#   t_15565_a_1_0000.nii.gz
#   t_15062_a_1_0000.nii.gz
#   t_8280_a_1_0000.nii.gz
#   t_15651_a_1_0000.nii.gz
#   t_10923_a_1_0000.nii.gz
#   t_13381_a_1_0000.nii.gz
#   t_19692_a_1_0000.nii.gz
#   t_5890_a_1_0000.nii.gz
#   t_8288_b_1_0000.nii.gz
#   t_8698_b_1_0000.nii.gz
#   t_4172_a_1_0000.nii.gz
#   t_9579_c_1_0000.nii.gz
#   t_2726_a_1_0000.nii.gz
#   t_11834_a_1_0000.nii.gz
#   t_12426_a_1_0000.nii.gz
#   t_13518_a_1_0000.nii.gz
#   t_3793_a_1_0000.nii.gz
#   t_12424_a_1_0000.nii.gz
#   t_7701_a_1_0000.nii.gz
#   t_7959_a_1_0000.nii.gz
#   t_2854_a_1_0000.nii.gz
#
# Files only in mask folder:
#   t_7293_a_1.nii.gz
#   t_12952_a_1.nii.gz
#   t_4603_a_1.nii.gz
#   t_5190_a_1.nii.gz
#   t_13720_a_1.nii.gz
#   t_15906_a_1.nii.gz
#   t_16666_a_1.nii.gz
#   t_10233_a_1.nii.gz
#   t_14728_a_1.nii.gz
#   t_9015_a_1.nii.gz
#   t_9714_a_1.nii.gz
#   t_14369_a_1.nii.gz
#   t_17367_a_1.nii.gz
#   t_18196_a_1.nii.gz
#   t_17197_a_1.nii.gz
#   t_15010_a_1.nii.gz
#   t_18730_a_1.nii.gz
#   t_18055_a_1.nii.gz
#   t_2296_a_1.nii.gz
#   t_2478_a_1.nii.gz
#   t_6440_a_1.nii.gz
#   t_13244_a_1.nii.gz
#   t_1385_a_1.nii.gz
#   t_13711_a_1.nii.gz
#   t_3799_a_1.nii.gz
#   t_4023_c_1.nii.gz
#   t_5359_a_1.nii.gz
#   t_17237_a_1.nii.gz
#   t_11303_a_1.nii.gz
#   t_6138_a_1.nii.gz
#   t_8785_a_1.nii.gz
#   t_10152_a_1.nii.gz
#   t_9820_a_1.nii.gz
#   t_7262_a_1.nii.gz
#   t_3686_a_1.nii.gz
#   t_16354_a_1.nii.gz
#   t_15965_a_1.nii.gz
#   t_8973_a_1.nii.gz
#   t_5816_a_1.nii.gz
#   t_5885_a_1.nii.gz
#   t_4514_b_1.nii.gz
#   t_184_a_1.nii.gz
#   t_7673_a_1.nii.gz
#   t_16107_a_1.nii.gz
#   t_11372_a_1.nii.gz
#   t_3145_a_1.nii.gz
#   t_7061_b_1.nii.gz
#   t_13339_a_1.nii.gz
#   t_6380_a_1.nii.gz
#   t_16525_a_1.nii.gz
#   t_15565_a_1.nii.gz
#   t_9059_a_1.nii.gz
#   t_8420_d_1.nii.gz
#   t_16384_a_1.nii.gz
#   t_1329_a_1.nii.gz
#   t_1545_a_1.nii.gz
#   t_14084_a_1.nii.gz
#   t_1700_a_1.nii.gz
#   t_11816_a_1.nii.gz
#   t_277_a_1.nii.gz
#   t_9346_a_1.nii.gz
#   t_1270_a_1.nii.gz
#   t_5992_a_1.nii.gz
#   t_11805_a_1.nii.gz
#   t_13714_a_1.nii.gz
#   t_8097_a_2.nii.gz
#   t_17268_a_1.nii.gz
#   t_8698_b_1.nii.gz
#   t_6035_b_1.nii.gz
#   t_3210_a_1.nii.gz
#   t_14142_a_1.nii.gz
#   t_14571_a_1.nii.gz
#   t_13077_a_1.nii.gz
#   t_1542_a_1.nii.gz
#   t_8565_a_1.nii.gz
#   t_15346_a_1.nii.gz
#   t_11010_a_1.nii.gz
#   t_174_a_1.nii.gz
#   t_8148_a_1.nii.gz
#   t_13826_a_1.nii.gz
#   t_8300_a_1.nii.gz
#   t_16896_a_1.nii.gz
#   t_9888_a_1.nii.gz
#   t_5682_a_1.nii.gz
#   t_2526_a_1.nii.gz
#   t_491_a_1.nii.gz
#   t_17293_a_1.nii.gz
#   t_16074_a_1.nii.gz
#   t_19915_a_1.nii.gz
#   t_12455_b_1.nii.gz
#   t_13147_a_1.nii.gz
#   t_18847_a_1.nii.gz
#   t_5618_a_1.nii.gz
#   t_12146_a_1.nii.gz
#   t_1600_a_1.nii.gz
#   t_12741_a_1.nii.gz
#   t_11594_a_1.nii.gz
#   t_3928_a_1.nii.gz
#   t_14000_a_1.nii.gz
#   t_13375_a_1.nii.gz
#   t_10483_a_1.nii.gz
#   t_14926_a_1.nii.gz
#   t_17421_a_1.nii.gz
#   t_17959_a_1.nii.gz
#   t_11963_a_1.nii.gz
#   t_13749_a_1.nii.gz
#   t_14876_a_1.nii.gz
#   t_4522_a_1.nii.gz
#   t_892_a_1.nii.gz
#   t_12563_b_1.nii.gz
#   t_3092_a_1.nii.gz
#   t_19245_a_1.nii.gz
#   t_6487_a_1.nii.gz
#   t_18798_a_1.nii.gz
#   t_15895_a_1.nii.gz
#   t_12699_a_1.nii.gz
#   t_742_a_1.nii.gz
#   t_17128_a_1.nii.gz
#   t_4944_a_1.nii.gz
#   t_1935_a_1.nii.gz
#   t_1516_b_1.nii.gz
#   t_7610_b_1.nii.gz
#   t_9702_a_1.nii.gz
#   t_11609_a_1.nii.gz
#   t_488_a_1.nii.gz
#   t_5074_a_1.nii.gz
#   t_8554_a_1.nii.gz
#   t_7650_a_1.nii.gz
#   t_10671_a_1.nii.gz
#   t_3723_a_1.nii.gz
#   t_19919_a_1.nii.gz
#   t_7487_a_1.nii.gz
#   t_1120_a_1.nii.gz
#   t_842_a_1.nii.gz
#   t_10591_a_1.nii.gz
#   t_4544_a_1.nii.gz
#   t_12627_a_1.nii.gz
#   t_5356_a_1.nii.gz
#   t_7259_a_1.nii.gz
#   t_8474_a_1.nii.gz
#   t_4489_a_1.nii.gz
#   t_7738_a_1.nii.gz
#   t_18612_a_1.nii.gz
#   t_9572_a_1.nii.gz
#   t_1378_a_1.nii.gz
#   t_14214_c_1.nii.gz
#   t_10311_a_1.nii.gz
#   t_10494_a_1.nii.gz
#   t_4379_a_1.nii.gz
#   t_19132_a_1.nii.gz
#   t_8556_a_1.nii.gz
#   t_921_a_1.nii.gz
#   t_18_a_1.nii.gz
#   t_10936_a_1.nii.gz
#   t_11952_a_1.nii.gz
#   t_9941_a_1.nii.gz
#   t_9756_a_1.nii.gz
#   t_4875_a_1.nii.gz
#   t_11186_b_1.nii.gz
#   t_10216_a_1.nii.gz
#   t_15292_a_1.nii.gz
#   t_14393_a_1.nii.gz
#   t_3787_a_1.nii.gz
#   t_66_a_1.nii.gz
#   t_7329_a_1.nii.gz
#   t_7604_a_1.nii.gz
#   t_7970_a_1.nii.gz
#   t_9106_a_1.nii.gz
#   t_19761_a_1.nii.gz
#   t_19401_a_1.nii.gz
#   t_11344_b_1.nii.gz
#   t_1267_a_1.nii.gz
#   t_6321_b_1.nii.gz
#   t_3286_a_1.nii.gz
#   t_10663_a_1.nii.gz
#   t_10731_a_1.nii.gz
#   t_2562_b_1.nii.gz
#   t_5815_a_1.nii.gz
#   t_501_a_1.nii.gz
#   t_13304_a_1.nii.gz
#   t_15137_a_1.nii.gz
#   t_6898_a_1.nii.gz
#   t_12551_a_1.nii.gz
#   t_9184_a_1.nii.gz
#   t_12040_a_1.nii.gz
#   t_15248_a_1.nii.gz
#   t_12372_a_1.nii.gz
#   t_16200_a_1.nii.gz
#   t_11115_a_1.nii.gz
#   t_5417_a_2.nii.gz
#   t_18353_a_1.nii.gz
#   t_4377_b_1.nii.gz
#   t_926_a_1.nii.gz
#   t_9806_a_1.nii.gz
#   t_131_a_1.nii.gz
#   t_10062_a_1.nii.gz
#   t_16254_a_1.nii.gz
#   t_9763_a_1.nii.gz
#   t_12717_a_1.nii.gz
#   t_12572_a_1.nii.gz
#   t_7843_a_1.nii.gz
#   t_9616_a_1.nii.gz
#   t_3138_a_1.nii.gz
#   t_14519_a_1.nii.gz
#   t_712_a_1.nii.gz
#   t_18486_a_1.nii.gz
#   t_10208_a_1.nii.gz
#   t_15430_a_1.nii.gz
#   t_18545_a_1.nii.gz
#   t_1507_a_1.nii.gz
#   t_18640_a_1.nii.gz
#   t_4467_a_1.nii.gz
#   t_13983_a_1.nii.gz
#   t_3080_a_1.nii.gz
#   t_16137_a_1.nii.gz
#   t_15799_a_1.nii.gz
#   t_18132_a_1.nii.gz
#   t_16010_a_1.nii.gz
#   t_18587_a_1.nii.gz
#   t_7223_a_1.nii.gz
#   t_5495_a_1.nii.gz
#   t_7368_a_1.nii.gz
#   t_1805_a_1.nii.gz
#   t_6283_a_1.nii.gz
#   t_10172_a_1.nii.gz
#   t_6794_a_1.nii.gz
#   t_12424_a_1.nii.gz
#   t_17324_a_1.nii.gz
#   t_10533_a_1.nii.gz
#   t_12849_a_1.nii.gz
#   t_18135_a_1.nii.gz
#   t_14431_a_1.nii.gz
#   t_12127_a_1.nii.gz
#   t_5754_a_1.nii.gz
#   t_6636_a_1.nii.gz
#   t_9559_a_1.nii.gz
#   t_7131_a_1.nii.gz
#   t_17453_c_1.nii.gz
#   t_3436_a_1.nii.gz
#   t_17148_a_1.nii.gz
#   t_19705_a_1.nii.gz
#   t_2275_a_1.nii.gz
#   t_18818_a_1.nii.gz
#   t_18154_a_1.nii.gz
#   t_19742_a_1.nii.gz
#   t_19692_a_1.nii.gz
#   t_784_a_1.nii.gz
#   t_12711_a_1.nii.gz
#   t_8288_b_1.nii.gz
#   t_6489_a_1.nii.gz
#   t_8280_a_1.nii.gz
#   t_662_c_1.nii.gz
#   t_10214_a_1.nii.gz
#   t_13639_a_1.nii.gz
#   t_84_a_1.nii.gz
#   t_454_a_1.nii.gz
#   t_8392_a_1.nii.gz
#   t_16606_a_1.nii.gz
#   t_5626_a_1.nii.gz
#   t_17874_a_1.nii.gz
#   t_440_b_1.nii.gz
#   t_15467_a_1.nii.gz
#   t_14601_a_1.nii.gz
#   t_3653_e_1.nii.gz
#   t_12426_a_1.nii.gz
#   t_3769_a_1.nii.gz
#   t_6835_b_1.nii.gz
#   t_9386_a_1.nii.gz
#   t_14987_a_1.nii.gz
#   t_8673_a_1.nii.gz
#   t_7815_a_1.nii.gz
#   t_8458_a_1.nii.gz
#   t_11469_a_1.nii.gz
#   t_16891_a_1.nii.gz
#   t_15358_a_1.nii.gz
#   t_6454_a_1.nii.gz
#   t_4786_a_1.nii.gz
#   t_16652_a_1.nii.gz
#   t_12520_a_1.nii.gz
#   t_9193_a_1.nii.gz
#   t_15645_a_1.nii.gz
#   t_11880_c_1.nii.gz
#   t_18754_a_1.nii.gz
#   t_10177_a_1.nii.gz
#   t_14376_a_2.nii.gz
#   t_9131_a_1.nii.gz
#   t_10860_a_1.nii.gz
#   t_10694_a_1.nii.gz
#   t_4592_a_1.nii.gz
#   t_14281_a_1.nii.gz
#   t_15062_a_1.nii.gz
#   t_8234_a_1.nii.gz
#   t_9521_a_1.nii.gz
#   t_16058_a_1.nii.gz
#   t_12912_a_1.nii.gz
#   t_9687_a_1.nii.gz
#   t_10592_a_1.nii.gz
#   t_14760_a_1.nii.gz
#   t_1322_a_1.nii.gz
#   t_15918_a_1.nii.gz
#   t_1901_a_1.nii.gz
#   t_19588_b_1.nii.gz
#   t_13300_a_1.nii.gz
#   t_18187_a_1.nii.gz
#   t_3052_a_1.nii.gz
#   t_4885_a_1.nii.gz
#   t_573_a_1.nii.gz
#   t_8779_a_1.nii.gz
#   t_2188_a_1.nii.gz
#   t_7054_a_1.nii.gz
#   t_4306_a_1.nii.gz
#   t_8912_a_1.nii.gz
#   t_2167_a_1.nii.gz
#   t_12000_a_1.nii.gz
#   t_1054_a_1.nii.gz
#   t_13118_a_1.nii.gz
#   t_5991_a_1.nii.gz
#   t_2823_a_1.nii.gz
#   t_18253_a_1.nii.gz
#   t_19797_a_1.nii.gz
#   t_8018_a_1.nii.gz
#   t_11834_a_1.nii.gz
#   t_13620_a_1.nii.gz
#   t_15274_a_1.nii.gz
#   t_9041_a_1.nii.gz
#   t_8093_a_1.nii.gz
#   t_9060_a_1.nii.gz
#   t_3173_b_1.nii.gz
#   t_18167_a_1.nii.gz
#   t_2990_a_1.nii.gz
#   t_5266_a_1.nii.gz
#   t_560_a_1.nii.gz
#   t_8278_a_1.nii.gz
#   t_10923_a_1.nii.gz
#   t_11126_a_1.nii.gz
#   t_6690_a_1.nii.gz
#   t_10473_b_1.nii.gz
#   t_11260_a_2.nii.gz
#   t_1734_a_1.nii.gz
#   t_14891_a_1.nii.gz
#   t_4671_a_1.nii.gz
#   t_10026_a_1.nii.gz
#   t_291_a_2.nii.gz
#   t_2306_a_1.nii.gz
#   t_3038_b_1.nii.gz
#   t_10039_a_1.nii.gz
#   t_18027_a_1.nii.gz
#   t_18098_a_1.nii.gz
#   t_17635_b_1.nii.gz
#   t_7085_a_1.nii.gz
#   t_2383_a_1.nii.gz
#   t_13692_a_1.nii.gz
#   t_13914_a_1.nii.gz
#   t_2888_a_1.nii.gz
#   t_5695_a_1.nii.gz
#   t_11602_a_1.nii.gz
#   t_838_a_1.nii.gz
#   t_19539_a_1.nii.gz
#   t_18997_a_1.nii.gz
#   t_5997_a_1.nii.gz
#   t_18600_a_1.nii.gz
#   t_16124_a_1.nii.gz
#   t_2936_a_1.nii.gz
#   t_6709_a_1.nii.gz
#   t_19875_b_1.nii.gz
#   t_18242_a_1.nii.gz
#   t_15508_a_1.nii.gz
#   t_3565_a_1.nii.gz
#   t_10271_a_1.nii.gz
#   t_11652_a_1.nii.gz
#   t_10438_a_1.nii.gz
#   t_14166_b_1.nii.gz
#   t_11658_a_1.nii.gz
#   t_12489_a_1.nii.gz
#   t_3710_a_1.nii.gz
#   t_7265_a_1.nii.gz
#   t_13942_a_1.nii.gz
#   t_1871_a_1.nii.gz
#   t_11946_a_1.nii.gz
#   t_14979_a_1.nii.gz
#   t_5395_a_1.nii.gz
#   t_11485_b_1.nii.gz
#   t_7288_a_1.nii.gz
#   t_15038_a_1.nii.gz
#   t_13599_a_1.nii.gz
#   t_1753_a_1.nii.gz
#   t_237_b_1.nii.gz
#   t_511_a_1.nii.gz
#   t_13888_a_1.nii.gz
#   t_8844_a_1.nii.gz
#   t_10845_a_1.nii.gz
#   t_8340_a_1.nii.gz
#   t_17869_a_1.nii.gz
#   t_19391_a_1.nii.gz
#   t_11038_a_1.nii.gz
#   t_19317_a_1.nii.gz
#   t_1706_d_1.nii.gz
#   t_8101_b_1.nii.gz
#   t_19191_b_1.nii.gz
#   t_1987_b_1.nii.gz
#   t_2574_b_1.nii.gz
#   t_3522_a_1.nii.gz
#   t_4988_a_1.nii.gz
#   t_11047_a_1.nii.gz
#   t_11960_a_1.nii.gz
#   t_2315_a_1.nii.gz
#   t_7912_a_1.nii.gz
#   t_18428_a_1.nii.gz
#   t_10908_a_1.nii.gz
#   t_8601_a_1.nii.gz
#   t_4433_a_1.nii.gz
#   t_1900_a_1.nii.gz
#   t_1958_a_1.nii.gz
#   t_15257_a_1.nii.gz
#   t_16949_a_1.nii.gz
#   t_2488_a_1.nii.gz
#   t_8342_a_1.nii.gz
#   t_3737_a_1.nii.gz
#   t_3174_a_1.nii.gz
#   t_4143_a_1.nii.gz
#   t_1018_a_2.nii.gz
#   t_8443_a_1.nii.gz
#   t_3003_a_1.nii.gz
#   t_5507_b_1.nii.gz
#   t_15078_a_1.nii.gz
#   t_15131_a_1.nii.gz
#   t_12361_a_1.nii.gz
#   t_11551_a_1.nii.gz
#   t_2319_a_1.nii.gz
#   t_3403_a_1.nii.gz
#   t_17315_a_1.nii.gz
#   t_12786_a_1.nii.gz
#   t_18956_a_1.nii.gz
#   t_13178_a_1.nii.gz
#   t_16831_a_1.nii.gz
#   t_2726_a_1.nii.gz
#   t_18757_a_1.nii.gz
#   t_10803_a_1.nii.gz
#   t_15494_a_1.nii.gz
#   t_19205_a_1.nii.gz
#   t_722_a_1.nii.gz
#   t_745_a_1.nii.gz
#   t_19524_a_1.nii.gz
#   t_4286_a_1.nii.gz
#   t_11315_g_1.nii.gz
#   t_19578_a_1.nii.gz
#   t_5000_b_1.nii.gz
#   t_16155_a_1.nii.gz
#   t_9329_a_1.nii.gz
#   t_16622_a_1.nii.gz
#   t_2928_a_1.nii.gz
#   t_3779_a_1.nii.gz
#   t_15502_a_1.nii.gz
#   t_2224_a_1.nii.gz
#   t_12077_a_1.nii.gz
#   t_2663_a_1.nii.gz
#   t_13213_a_1.nii.gz
#   t_3880_a_1.nii.gz
#   t_1440_a_1.nii.gz
#   t_9484_a_1.nii.gz
#   t_8773_a_1.nii.gz
#   t_16390_a_1.nii.gz
#   t_4172_a_1.nii.gz
#   t_7804_a_1.nii.gz
#   t_19279_c_1.nii.gz
#   t_13970_a_1.nii.gz
#   t_6132_a_1.nii.gz
#   t_6175_a_1.nii.gz
#   t_4029_a_1.nii.gz
#   t_1214_a_1.nii.gz
#   t_7845_b_1.nii.gz
#   t_6072_a_1.nii.gz
#   t_10981_b_1.nii.gz
#   t_11850_a_1.nii.gz
#   t_14832_a_1.nii.gz
#   t_7602_a_1.nii.gz
#   t_9507_a_1.nii.gz
#   t_2898_a_1.nii.gz
#   t_8898_a_1.nii.gz
#   t_17514_a_1.nii.gz
#   t_14947_c_1.nii.gz
#   t_17631_a_1.nii.gz
#   t_19219_b_1.nii.gz
#   t_15856_a_1.nii.gz
#   t_7834_b_1.nii.gz
#   t_13151_a_1.nii.gz
#   t_6907_a_1.nii.gz
#   t_2541_b_1.nii.gz
#   t_14984_a_1.nii.gz
#   t_2620_a_1.nii.gz
#   t_6482_a_2.nii.gz
#   t_754_a_1.nii.gz
#   t_17924_a_1.nii.gz
#   t_11174_a_1.nii.gz
#   t_10393_a_1.nii.gz
#   t_16718_a_1.nii.gz
#   t_6797_a_1.nii.gz
#   t_17708_a_1.nii.gz
#   t_50_a_1.nii.gz
#   t_8055_a_1.nii.gz
#   t_16132_a_1.nii.gz
#   t_1205_a_1.nii.gz
#   t_18341_a_1.nii.gz
#   t_7328_a_1.nii.gz
#   t_16235_a_1.nii.gz
#   t_6932_a_1.nii.gz
#   t_14763_a_1.nii.gz
#   t_16070_a_1.nii.gz
#   t_641_a_1.nii.gz
#   t_8222_a_1.nii.gz
#   t_12387_a_1.nii.gz
#   t_8756_a_1.nii.gz
#   t_3796_a_1.nii.gz
#   t_8112_a_1.nii.gz
#   t_8464_a_1.nii.gz
#   t_7117_a_1.nii.gz
#   t_17813_a_1.nii.gz
#   t_9972_a_1.nii.gz
#   t_18693_a_1.nii.gz
#   t_5437_a_1.nii.gz
#   t_11388_a_1.nii.gz
#   t_19627_a_1.nii.gz
#   t_18636_a_1.nii.gz
#   t_14648_a_1.nii.gz
#   t_15488_a_1.nii.gz
#   t_2160_a_1.nii.gz
#   t_2854_a_1.nii.gz
#   t_1086_a_1.nii.gz
#   t_14401_a_1.nii.gz
#   t_3268_a_1.nii.gz
#   t_7346_a_1.nii.gz
#   t_19874_a_1.nii.gz
#   t_8323_a_1.nii.gz
#   t_7756_a_1.nii.gz
#   t_6375_a_1.nii.gz
#   t_19482_a_1.nii.gz
#   t_604_a_2.nii.gz
#   t_11797_a_1.nii.gz
#   t_15206_a_1.nii.gz
#   t_17623_a_1.nii.gz
#   t_17592_a_1.nii.gz
#   t_17999_c_1.nii.gz
#   t_19999_a_1.nii.gz
#   t_11273_a_1.nii.gz
#   t_1229_a_1.nii.gz
#   t_8981_a_1.nii.gz
#   t_19109_a_1.nii.gz
#   t_19529_a_1.nii.gz
#   t_3793_a_1.nii.gz
#   t_19909_a_1.nii.gz
#   t_2529_a_1.nii.gz
#   t_1395_a_1.nii.gz
#   t_13113_a_1.nii.gz
#   t_19093_b_1.nii.gz
#   t_3018_a_1.nii.gz
#   t_3603_a_1.nii.gz
#   t_5261_a_1.nii.gz
#   t_7058_a_1.nii.gz
#   t_11281_a_1.nii.gz
#   t_13380_a_1.nii.gz
#   t_16619_a_1.nii.gz
#   t_19781_a_1.nii.gz
#   t_2025_a_1.nii.gz
#   t_5817_b_1.nii.gz
#   t_6359_a_1.nii.gz
#   t_6672_a_1.nii.gz
#   t_350_a_1.nii.gz
#   t_16741_a_1.nii.gz
#   t_15857_a_1.nii.gz
#   t_4436_b_1.nii.gz
#   t_7481_a_1.nii.gz
#   t_17778_a_1.nii.gz
#   t_10782_a_1.nii.gz
#   t_11613_a_1.nii.gz
#   t_5594_a_1.nii.gz
#   t_15632_a_1.nii.gz
#   t_8418_a_1.nii.gz
#   t_112_a_1.nii.gz
#   t_6902_b_1.nii.gz
#   t_7883_a_1.nii.gz
#   t_3772_a_1.nii.gz
#   t_5257_a_1.nii.gz
#   t_15629_a_1.nii.gz
#   t_18983_a_1.nii.gz
#   t_4504_b_1.nii.gz
#   t_6918_a_1.nii.gz
#   t_6328_a_1.nii.gz
#   t_7959_a_1.nii.gz
#   t_18477_a_1.nii.gz
#   t_17202_a_1.nii.gz
#   t_17562_a_1.nii.gz
#   t_11026_a_1.nii.gz
#   t_3583_a_1.nii.gz
#   t_13301_b_1.nii.gz
#   t_8890_a_1.nii.gz
#   t_4429_a_1.nii.gz
#   t_5030_a_1.nii.gz
#   t_11132_a_1.nii.gz
#   t_12595_a_1.nii.gz
#   t_14837_a_1.nii.gz
#   t_14489_a_1.nii.gz
#   t_10987_a_1.nii.gz
#   t_15065_a_1.nii.gz
#   t_13202_c_1.nii.gz
#   t_5890_a_1.nii.gz
#   t_11453_a_1.nii.gz
#   t_4717_a_1.nii.gz
#   t_288_a_1.nii.gz
#   t_19173_a_1.nii.gz
#   t_2262_a_1.nii.gz
#   t_16761_a_1.nii.gz
#   t_18746_a_1.nii.gz
#   t_4314_a_1.nii.gz
#   t_16547_a_1.nii.gz
#   t_1792_a_1.nii.gz
#   t_1522_a_1.nii.gz
#   t_5235_a_1.nii.gz
#   t_18840_b_1.nii.gz
#   t_13518_a_1.nii.gz
#   t_6274_a_1.nii.gz
#   t_12631_a_1.nii.gz
#   t_14323_a_1.nii.gz
#   t_4051_a_1.nii.gz
#   t_16790_a_1.nii.gz
#   t_3088_a_1.nii.gz
#   t_7974_a_1.nii.gz
#   t_1437_b_1.nii.gz
#   t_7530_a_1.nii.gz
#   t_11476_a_1.nii.gz
#   t_15940_b_1.nii.gz
#   t_18717_e_1.nii.gz
#   t_14554_a_1.nii.gz
#   t_13892_a_1.nii.gz
#   t_15240_a_1.nii.gz
#   t_924_a_1.nii.gz
#   t_17998_a_1.nii.gz
#   t_2704_a_1.nii.gz
#   t_19852_a_1.nii.gz
#   t_6759_a_1.nii.gz
#   t_17553_a_1.nii.gz
#   t_18753_a_1.nii.gz
#   t_5597_a_1.nii.gz
#   t_11066_a_1.nii.gz
#   t_11432_a_1.nii.gz
#   t_13036_a_1.nii.gz
#   t_7236_a_1.nii.gz
#   t_11421_a_1.nii.gz
#   t_19274_a_1.nii.gz
#   t_7240_a_1.nii.gz
#   t_8974_a_1.nii.gz
#   t_6047_b_1.nii.gz
#   t_807_a_1.nii.gz
#   t_17276_a_1.nii.gz
#   t_18616_a_1.nii.gz
#   t_5725_a_1.nii.gz
#   t_16088_a_1.nii.gz
#   t_13276_a_1.nii.gz
#   t_11867_a_1.nii.gz
#   t_790_a_1.nii.gz
#   t_6669_a_1.nii.gz
#   t_13824_b_1.nii.gz
#   t_17426_a_1.nii.gz
#   t_8132_a_1.nii.gz
#   t_3143_a_1.nii.gz
#   t_7644_a_1.nii.gz
#   t_2689_a_1.nii.gz
#   t_2987_a_1.nii.gz
#   t_18821_a_1.nii.gz
#   t_10549_a_1.nii.gz
#   t_14632_a_1.nii.gz
#   t_15156_a_1.nii.gz
#   t_4199_a_1.nii.gz
#   t_14746_a_1.nii.gz
#   t_19772_a_1.nii.gz
#   t_2408_a_1.nii.gz
#   t_11956_a_1.nii.gz
#   t_2481_a_1.nii.gz
#   t_18163_a_1.nii.gz
#   t_7220_a_1.nii.gz
#   t_15157_a_1.nii.gz
#   t_19962_a_1.nii.gz
#   t_10983_a_1.nii.gz
#   t_17615_a_1.nii.gz
#   t_5989_a_1.nii.gz
#   t_9158_a_1.nii.gz
#   t_10572_a_1.nii.gz
#   t_4193_a_1.nii.gz
#   t_7701_a_1.nii.gz
#   t_10596_a_1.nii.gz
#   t_10296_b_1.nii.gz
#   t_2344_a_1.nii.gz
#   t_7079_a_1.nii.gz
#   t_12049_a_1.nii.gz
#   t_13381_a_1.nii.gz
#   t_10319_a_1.nii.gz
#   t_18839_a_1.nii.gz
#   t_6581_a_1.nii.gz
#   t_1464_a_1.nii.gz
#   t_19283_a_1.nii.gz
#   t_2187_a_1.nii.gz
#   t_19817_a_1.nii.gz
#   t_13958_a_1.nii.gz
#   t_8549_c_1.nii.gz
#   t_19956_a_1.nii.gz
#   t_7002_a_1.nii.gz
#   t_9055_a_1.nii.gz
#   t_916_a_1.nii.gz
#   t_621_a_1.nii.gz
#   t_18684_a_1.nii.gz
#   t_19450_a_1.nii.gz
#   t_8535_a_1.nii.gz
#   t_6130_b_1.nii.gz
#   t_10310_a_1.nii.gz
#   t_19166_a_1.nii.gz
#   t_19599_a_1.nii.gz
#   t_7667_a_1.nii.gz
#   t_9630_a_1.nii.gz
#   t_1680_a_1.nii.gz
#   t_12136_a_1.nii.gz
#   t_18153_a_1.nii.gz
#   t_9245_a_1.nii.gz
#   t_18791_a_1.nii.gz
#   t_12486_a_1.nii.gz
#   t_15203_a_1.nii.gz
#   t_8030_a_1.nii.gz
#   t_17328_a_1.nii.gz
#   t_2991_a_1.nii.gz
#   t_7841_a_1.nii.gz
#   t_8270_a_1.nii.gz
#   t_9970_a_1.nii.gz
#   t_966_a_1.nii.gz
#   t_14169_a_1.nii.gz
#   t_512_a_1.nii.gz
#   t_11095_a_1.nii.gz
#   t_11669_a_1.nii.gz
#   t_4772_a_1.nii.gz
#   t_7157_a_1.nii.gz
#   t_8871_a_1.nii.gz
#   t_8886_a_1.nii.gz
#   t_10627_a_1.nii.gz
#   t_15651_a_1.nii.gz
#   t_6688_b_1.nii.gz
#   t_992_a_1.nii.gz
#   t_12874_a_1.nii.gz
#   t_3912_a_1.nii.gz
#   t_3144_a_1.nii.gz
#   t_8330_a_1.nii.gz
#   t_727_a_1.nii.gz
#   t_15410_a_1.nii.gz
#   t_10955_a_1.nii.gz
#   t_18978_a_1.nii.gz
#   t_14990_a_1.nii.gz
#   t_14796_a_1.nii.gz
#   t_3918_a_1.nii.gz
#   t_8837_a_1.nii.gz
#   t_17602_a_1.nii.gz
#   t_6960_a_1.nii.gz
#   t_10604_a_1.nii.gz
#   t_18988_a_1.nii.gz
#   t_16825_a_1.nii.gz
#   t_1942_a_1.nii.gz
#   t_16951_b_1.nii.gz
#   t_6443_a_1.nii.gz
#   t_7692_a_1.nii.gz
#   t_15047_a_1.nii.gz
#   t_9579_c_1.nii.gz
#   t_15880_a_1.nii.gz
#   t_14574_a_1.nii.gz
#   t_3641_a_1.nii.gz
#   t_860_a_1.nii.gz
#
# Common files:
#
# Checking filename patterns:
#   Files in mask folder without '_0000':
#     t_10026_a_1.nii.gz
#     t_10039_a_1.nii.gz
#     t_10062_a_1.nii.gz
#     t_10152_a_1.nii.gz
#     t_10172_a_1.nii.gz
#     t_10177_a_1.nii.gz
#     t_1018_a_2.nii.gz
#     t_10208_a_1.nii.gz
#     t_10214_a_1.nii.gz
#     t_10216_a_1.nii.gz
#     t_10233_a_1.nii.gz
#     t_10271_a_1.nii.gz
#     t_10296_b_1.nii.gz
#     t_10310_a_1.nii.gz
#     t_10311_a_1.nii.gz
#     t_10319_a_1.nii.gz
#     t_10393_a_1.nii.gz
#     t_10438_a_1.nii.gz
#     t_10473_b_1.nii.gz
#     t_10483_a_1.nii.gz
#     t_10494_a_1.nii.gz
#     t_10533_a_1.nii.gz
#     t_10549_a_1.nii.gz
#     t_1054_a_1.nii.gz
#     t_10572_a_1.nii.gz
#     t_10591_a_1.nii.gz
#     t_10592_a_1.nii.gz
#     t_10596_a_1.nii.gz
#     t_10604_a_1.nii.gz
#     t_10627_a_1.nii.gz
#     t_10663_a_1.nii.gz
#     t_10671_a_1.nii.gz
#     t_10694_a_1.nii.gz
#     t_10731_a_1.nii.gz
#     t_10782_a_1.nii.gz
#     t_10803_a_1.nii.gz
#     t_10845_a_1.nii.gz
#     t_10860_a_1.nii.gz
#     t_1086_a_1.nii.gz
#     t_10908_a_1.nii.gz
#     t_10923_a_1.nii.gz
#     t_10936_a_1.nii.gz
#     t_10955_a_1.nii.gz
#     t_10981_b_1.nii.gz
#     t_10983_a_1.nii.gz
#     t_10987_a_1.nii.gz
#     t_11010_a_1.nii.gz
#     t_11026_a_1.nii.gz
#     t_11038_a_1.nii.gz
#     t_11047_a_1.nii.gz
#     t_11066_a_1.nii.gz
#     t_11095_a_1.nii.gz
#     t_11115_a_1.nii.gz
#     t_11126_a_1.nii.gz
#     t_11132_a_1.nii.gz
#     t_11174_a_1.nii.gz
#     t_11186_b_1.nii.gz
#     t_1120_a_1.nii.gz
#     t_11260_a_2.nii.gz
#     t_11273_a_1.nii.gz
#     t_11281_a_1.nii.gz
#     t_112_a_1.nii.gz
#     t_11303_a_1.nii.gz
#     t_11315_g_1.nii.gz
#     t_11344_b_1.nii.gz
#     t_11372_a_1.nii.gz
#     t_11388_a_1.nii.gz
#     t_11421_a_1.nii.gz
#     t_11432_a_1.nii.gz
#     t_11453_a_1.nii.gz
#     t_11469_a_1.nii.gz
#     t_11476_a_1.nii.gz
#     t_11485_b_1.nii.gz
#     t_11551_a_1.nii.gz
#     t_11594_a_1.nii.gz
#     t_11602_a_1.nii.gz
#     t_11609_a_1.nii.gz
#     t_11613_a_1.nii.gz
#     t_11652_a_1.nii.gz
#     t_11658_a_1.nii.gz
#     t_11669_a_1.nii.gz
#     t_11797_a_1.nii.gz
#     t_11805_a_1.nii.gz
#     t_11816_a_1.nii.gz
#     t_11834_a_1.nii.gz
#     t_11850_a_1.nii.gz
#     t_11867_a_1.nii.gz
#     t_11880_c_1.nii.gz
#     t_11946_a_1.nii.gz
#     t_11952_a_1.nii.gz
#     t_11956_a_1.nii.gz
#     t_11960_a_1.nii.gz
#     t_11963_a_1.nii.gz
#     t_12000_a_1.nii.gz
#     t_12040_a_1.nii.gz
#     t_12049_a_1.nii.gz
#     t_1205_a_1.nii.gz
#     t_12077_a_1.nii.gz
#     t_12127_a_1.nii.gz
#     t_12136_a_1.nii.gz
#     t_12146_a_1.nii.gz
#     t_1214_a_1.nii.gz
#     t_1229_a_1.nii.gz
#     t_12361_a_1.nii.gz
#     t_12372_a_1.nii.gz
#     t_12387_a_1.nii.gz
#     t_12424_a_1.nii.gz
#     t_12426_a_1.nii.gz
#     t_12455_b_1.nii.gz
#     t_12486_a_1.nii.gz
#     t_12489_a_1.nii.gz
#     t_12520_a_1.nii.gz
#     t_12551_a_1.nii.gz
#     t_12563_b_1.nii.gz
#     t_12572_a_1.nii.gz
#     t_12595_a_1.nii.gz
#     t_12627_a_1.nii.gz
#     t_12631_a_1.nii.gz
#     t_1267_a_1.nii.gz
#     t_12699_a_1.nii.gz
#     t_1270_a_1.nii.gz
#     t_12711_a_1.nii.gz
#     t_12717_a_1.nii.gz
#     t_12741_a_1.nii.gz
#     t_12786_a_1.nii.gz
#     t_12849_a_1.nii.gz
#     t_12874_a_1.nii.gz
#     t_12912_a_1.nii.gz
#     t_12952_a_1.nii.gz
#     t_13036_a_1.nii.gz
#     t_13077_a_1.nii.gz
#     t_13113_a_1.nii.gz
#     t_13118_a_1.nii.gz
#     t_13147_a_1.nii.gz
#     t_13151_a_1.nii.gz
#     t_13178_a_1.nii.gz
#     t_131_a_1.nii.gz
#     t_13202_c_1.nii.gz
#     t_13213_a_1.nii.gz
#     t_1322_a_1.nii.gz
#     t_13244_a_1.nii.gz
#     t_13276_a_1.nii.gz
#     t_1329_a_1.nii.gz
#     t_13300_a_1.nii.gz
#     t_13301_b_1.nii.gz
#     t_13304_a_1.nii.gz
#     t_13339_a_1.nii.gz
#     t_13375_a_1.nii.gz
#     t_13380_a_1.nii.gz
#     t_13381_a_1.nii.gz
#     t_13518_a_1.nii.gz
#     t_13599_a_1.nii.gz
#     t_13620_a_1.nii.gz
#     t_13639_a_1.nii.gz
#     t_13692_a_1.nii.gz
#     t_13711_a_1.nii.gz
#     t_13714_a_1.nii.gz
#     t_13720_a_1.nii.gz
#     t_13749_a_1.nii.gz
#     t_1378_a_1.nii.gz
#     t_13824_b_1.nii.gz
#     t_13826_a_1.nii.gz
#     t_1385_a_1.nii.gz
#     t_13888_a_1.nii.gz
#     t_13892_a_1.nii.gz
#     t_13914_a_1.nii.gz
#     t_13942_a_1.nii.gz
#     t_13958_a_1.nii.gz
#     t_1395_a_1.nii.gz
#     t_13970_a_1.nii.gz
#     t_13983_a_1.nii.gz
#     t_14000_a_1.nii.gz
#     t_14084_a_1.nii.gz
#     t_14142_a_1.nii.gz
#     t_14166_b_1.nii.gz
#     t_14169_a_1.nii.gz
#     t_14214_c_1.nii.gz
#     t_14281_a_1.nii.gz
#     t_14323_a_1.nii.gz
#     t_14369_a_1.nii.gz
#     t_14376_a_2.nii.gz
#     t_1437_b_1.nii.gz
#     t_14393_a_1.nii.gz
#     t_14401_a_1.nii.gz
#     t_1440_a_1.nii.gz
#     t_14431_a_1.nii.gz
#     t_14489_a_1.nii.gz
#     t_14519_a_1.nii.gz
#     t_14554_a_1.nii.gz
#     t_14571_a_1.nii.gz
#     t_14574_a_1.nii.gz
#     t_14601_a_1.nii.gz
#     t_14632_a_1.nii.gz
#     t_14648_a_1.nii.gz
#     t_1464_a_1.nii.gz
#     t_14728_a_1.nii.gz
#     t_14746_a_1.nii.gz
#     t_14760_a_1.nii.gz
#     t_14763_a_1.nii.gz
#     t_14796_a_1.nii.gz
#     t_14832_a_1.nii.gz
#     t_14837_a_1.nii.gz
#     t_14876_a_1.nii.gz
#     t_14891_a_1.nii.gz
#     t_14926_a_1.nii.gz
#     t_14947_c_1.nii.gz
#     t_14979_a_1.nii.gz
#     t_14984_a_1.nii.gz
#     t_14987_a_1.nii.gz
#     t_14990_a_1.nii.gz
#     t_15010_a_1.nii.gz
#     t_15038_a_1.nii.gz
#     t_15047_a_1.nii.gz
#     t_15062_a_1.nii.gz
#     t_15065_a_1.nii.gz
#     t_15078_a_1.nii.gz
#     t_1507_a_1.nii.gz
#     t_15131_a_1.nii.gz
#     t_15137_a_1.nii.gz
#     t_15156_a_1.nii.gz
#     t_15157_a_1.nii.gz
#     t_1516_b_1.nii.gz
#     t_15203_a_1.nii.gz
#     t_15206_a_1.nii.gz
#     t_1522_a_1.nii.gz
#     t_15240_a_1.nii.gz
#     t_15248_a_1.nii.gz
#     t_15257_a_1.nii.gz
#     t_15274_a_1.nii.gz
#     t_15292_a_1.nii.gz
#     t_15346_a_1.nii.gz
#     t_15358_a_1.nii.gz
#     t_15410_a_1.nii.gz
#     t_1542_a_1.nii.gz
#     t_15430_a_1.nii.gz
#     t_1545_a_1.nii.gz
#     t_15467_a_1.nii.gz
#     t_15488_a_1.nii.gz
#     t_15494_a_1.nii.gz
#     t_15502_a_1.nii.gz
#     t_15508_a_1.nii.gz
#     t_15565_a_1.nii.gz
#     t_15629_a_1.nii.gz
#     t_15632_a_1.nii.gz
#     t_15645_a_1.nii.gz
#     t_15651_a_1.nii.gz
#     t_15799_a_1.nii.gz
#     t_15856_a_1.nii.gz
#     t_15857_a_1.nii.gz
#     t_15880_a_1.nii.gz
#     t_15895_a_1.nii.gz
#     t_15906_a_1.nii.gz
#     t_15918_a_1.nii.gz
#     t_15940_b_1.nii.gz
#     t_15965_a_1.nii.gz
#     t_1600_a_1.nii.gz
#     t_16010_a_1.nii.gz
#     t_16058_a_1.nii.gz
#     t_16070_a_1.nii.gz
#     t_16074_a_1.nii.gz
#     t_16088_a_1.nii.gz
#     t_16107_a_1.nii.gz
#     t_16124_a_1.nii.gz
#     t_16132_a_1.nii.gz
#     t_16137_a_1.nii.gz
#     t_16155_a_1.nii.gz
#     t_16200_a_1.nii.gz
#     t_16235_a_1.nii.gz
#     t_16254_a_1.nii.gz
#     t_16354_a_1.nii.gz
#     t_16384_a_1.nii.gz
#     t_16390_a_1.nii.gz
#     t_16525_a_1.nii.gz
#     t_16547_a_1.nii.gz
#     t_16606_a_1.nii.gz
#     t_16619_a_1.nii.gz
#     t_16622_a_1.nii.gz
#     t_16652_a_1.nii.gz
#     t_16666_a_1.nii.gz
#     t_16718_a_1.nii.gz
#     t_16741_a_1.nii.gz
#     t_16761_a_1.nii.gz
#     t_16790_a_1.nii.gz
#     t_1680_a_1.nii.gz
#     t_16825_a_1.nii.gz
#     t_16831_a_1.nii.gz
#     t_16891_a_1.nii.gz
#     t_16896_a_1.nii.gz
#     t_16949_a_1.nii.gz
#     t_16951_b_1.nii.gz
#     t_1700_a_1.nii.gz
#     t_1706_d_1.nii.gz
#     t_17128_a_1.nii.gz
#     t_17148_a_1.nii.gz
#     t_17197_a_1.nii.gz
#     t_17202_a_1.nii.gz
#     t_17237_a_1.nii.gz
#     t_17268_a_1.nii.gz
#     t_17276_a_1.nii.gz
#     t_17293_a_1.nii.gz
#     t_17315_a_1.nii.gz
#     t_17324_a_1.nii.gz
#     t_17328_a_1.nii.gz
#     t_1734_a_1.nii.gz
#     t_17367_a_1.nii.gz
#     t_17421_a_1.nii.gz
#     t_17426_a_1.nii.gz
#     t_17453_c_1.nii.gz
#     t_174_a_1.nii.gz
#     t_17514_a_1.nii.gz
#     t_1753_a_1.nii.gz
#     t_17553_a_1.nii.gz
#     t_17562_a_1.nii.gz
#     t_17592_a_1.nii.gz
#     t_17602_a_1.nii.gz
#     t_17615_a_1.nii.gz
#     t_17623_a_1.nii.gz
#     t_17631_a_1.nii.gz
#     t_17635_b_1.nii.gz
#     t_17708_a_1.nii.gz
#     t_17778_a_1.nii.gz
#     t_17813_a_1.nii.gz
#     t_17869_a_1.nii.gz
#     t_17874_a_1.nii.gz
#     t_17924_a_1.nii.gz
#     t_1792_a_1.nii.gz
#     t_17959_a_1.nii.gz
#     t_17998_a_1.nii.gz
#     t_17999_c_1.nii.gz
#     t_18027_a_1.nii.gz
#     t_18055_a_1.nii.gz
#     t_1805_a_1.nii.gz
#     t_18098_a_1.nii.gz
#     t_18132_a_1.nii.gz
#     t_18135_a_1.nii.gz
#     t_18153_a_1.nii.gz
#     t_18154_a_1.nii.gz
#     t_18163_a_1.nii.gz
#     t_18167_a_1.nii.gz
#     t_18187_a_1.nii.gz
#     t_18196_a_1.nii.gz
#     t_18242_a_1.nii.gz
#     t_18253_a_1.nii.gz
#     t_18341_a_1.nii.gz
#     t_18353_a_1.nii.gz
#     t_18428_a_1.nii.gz
#     t_18477_a_1.nii.gz
#     t_18486_a_1.nii.gz
#     t_184_a_1.nii.gz
#     t_18545_a_1.nii.gz
#     t_18587_a_1.nii.gz
#     t_18600_a_1.nii.gz
#     t_18612_a_1.nii.gz
#     t_18616_a_1.nii.gz
#     t_18636_a_1.nii.gz
#     t_18640_a_1.nii.gz
#     t_18684_a_1.nii.gz
#     t_18693_a_1.nii.gz
#     t_18717_e_1.nii.gz
#     t_1871_a_1.nii.gz
#     t_18730_a_1.nii.gz
#     t_18746_a_1.nii.gz
#     t_18753_a_1.nii.gz
#     t_18754_a_1.nii.gz
#     t_18757_a_1.nii.gz
#     t_18791_a_1.nii.gz
#     t_18798_a_1.nii.gz
#     t_18818_a_1.nii.gz
#     t_18821_a_1.nii.gz
#     t_18839_a_1.nii.gz
#     t_18840_b_1.nii.gz
#     t_18847_a_1.nii.gz
#     t_18956_a_1.nii.gz
#     t_18978_a_1.nii.gz
#     t_18983_a_1.nii.gz
#     t_18988_a_1.nii.gz
#     t_18997_a_1.nii.gz
#     t_18_a_1.nii.gz
#     t_1900_a_1.nii.gz
#     t_1901_a_1.nii.gz
#     t_19093_b_1.nii.gz
#     t_19109_a_1.nii.gz
#     t_19132_a_1.nii.gz
#     t_19166_a_1.nii.gz
#     t_19173_a_1.nii.gz
#     t_19191_b_1.nii.gz
#     t_19205_a_1.nii.gz
#     t_19219_b_1.nii.gz
#     t_19245_a_1.nii.gz
#     t_19274_a_1.nii.gz
#     t_19279_c_1.nii.gz
#     t_19283_a_1.nii.gz
#     t_19317_a_1.nii.gz
#     t_1935_a_1.nii.gz
#     t_19391_a_1.nii.gz
#     t_19401_a_1.nii.gz
#     t_1942_a_1.nii.gz
#     t_19450_a_1.nii.gz
#     t_19482_a_1.nii.gz
#     t_19524_a_1.nii.gz
#     t_19529_a_1.nii.gz
#     t_19539_a_1.nii.gz
#     t_19578_a_1.nii.gz
#     t_19588_b_1.nii.gz
#     t_1958_a_1.nii.gz
#     t_19599_a_1.nii.gz
#     t_19627_a_1.nii.gz
#     t_19692_a_1.nii.gz
#     t_19705_a_1.nii.gz
#     t_19742_a_1.nii.gz
#     t_19761_a_1.nii.gz
#     t_19772_a_1.nii.gz
#     t_19781_a_1.nii.gz
#     t_19797_a_1.nii.gz
#     t_19817_a_1.nii.gz
#     t_19852_a_1.nii.gz
#     t_19874_a_1.nii.gz
#     t_19875_b_1.nii.gz
#     t_1987_b_1.nii.gz
#     t_19909_a_1.nii.gz
#     t_19915_a_1.nii.gz
#     t_19919_a_1.nii.gz
#     t_19956_a_1.nii.gz
#     t_19962_a_1.nii.gz
#     t_19999_a_1.nii.gz
#     t_2025_a_1.nii.gz
#     t_2160_a_1.nii.gz
#     t_2167_a_1.nii.gz
#     t_2187_a_1.nii.gz
#     t_2188_a_1.nii.gz
#     t_2224_a_1.nii.gz
#     t_2262_a_1.nii.gz
#     t_2275_a_1.nii.gz
#     t_2296_a_1.nii.gz
#     t_2306_a_1.nii.gz
#     t_2315_a_1.nii.gz
#     t_2319_a_1.nii.gz
#     t_2344_a_1.nii.gz
#     t_237_b_1.nii.gz
#     t_2383_a_1.nii.gz
#     t_2408_a_1.nii.gz
#     t_2478_a_1.nii.gz
#     t_2481_a_1.nii.gz
#     t_2488_a_1.nii.gz
#     t_2526_a_1.nii.gz
#     t_2529_a_1.nii.gz
#     t_2541_b_1.nii.gz
#     t_2562_b_1.nii.gz
#     t_2574_b_1.nii.gz
#     t_2620_a_1.nii.gz
#     t_2663_a_1.nii.gz
#     t_2689_a_1.nii.gz
#     t_2704_a_1.nii.gz
#     t_2726_a_1.nii.gz
#     t_277_a_1.nii.gz
#     t_2823_a_1.nii.gz
#     t_2854_a_1.nii.gz
#     t_2888_a_1.nii.gz
#     t_288_a_1.nii.gz
#     t_2898_a_1.nii.gz
#     t_291_a_2.nii.gz
#     t_2928_a_1.nii.gz
#     t_2936_a_1.nii.gz
#     t_2987_a_1.nii.gz
#     t_2990_a_1.nii.gz
#     t_2991_a_1.nii.gz
#     t_3003_a_1.nii.gz
#     t_3018_a_1.nii.gz
#     t_3038_b_1.nii.gz
#     t_3052_a_1.nii.gz
#     t_3080_a_1.nii.gz
#     t_3088_a_1.nii.gz
#     t_3092_a_1.nii.gz
#     t_3138_a_1.nii.gz
#     t_3143_a_1.nii.gz
#     t_3144_a_1.nii.gz
#     t_3145_a_1.nii.gz
#     t_3173_b_1.nii.gz
#     t_3174_a_1.nii.gz
#     t_3210_a_1.nii.gz
#     t_3268_a_1.nii.gz
#     t_3286_a_1.nii.gz
#     t_3403_a_1.nii.gz
#     t_3436_a_1.nii.gz
#     t_350_a_1.nii.gz
#     t_3522_a_1.nii.gz
#     t_3565_a_1.nii.gz
#     t_3583_a_1.nii.gz
#     t_3603_a_1.nii.gz
#     t_3641_a_1.nii.gz
#     t_3653_e_1.nii.gz
#     t_3686_a_1.nii.gz
#     t_3710_a_1.nii.gz
#     t_3723_a_1.nii.gz
#     t_3737_a_1.nii.gz
#     t_3769_a_1.nii.gz
#     t_3772_a_1.nii.gz
#     t_3779_a_1.nii.gz
#     t_3787_a_1.nii.gz
#     t_3793_a_1.nii.gz
#     t_3796_a_1.nii.gz
#     t_3799_a_1.nii.gz
#     t_3880_a_1.nii.gz
#     t_3912_a_1.nii.gz
#     t_3918_a_1.nii.gz
#     t_3928_a_1.nii.gz
#     t_4023_c_1.nii.gz
#     t_4029_a_1.nii.gz
#     t_4051_a_1.nii.gz
#     t_4143_a_1.nii.gz
#     t_4172_a_1.nii.gz
#     t_4193_a_1.nii.gz
#     t_4199_a_1.nii.gz
#     t_4286_a_1.nii.gz
#     t_4306_a_1.nii.gz
#     t_4314_a_1.nii.gz
#     t_4377_b_1.nii.gz
#     t_4379_a_1.nii.gz
#     t_440_b_1.nii.gz
#     t_4429_a_1.nii.gz
#     t_4433_a_1.nii.gz
#     t_4436_b_1.nii.gz
#     t_4467_a_1.nii.gz
#     t_4489_a_1.nii.gz
#     t_4504_b_1.nii.gz
#     t_4514_b_1.nii.gz
#     t_4522_a_1.nii.gz
#     t_4544_a_1.nii.gz
#     t_454_a_1.nii.gz
#     t_4592_a_1.nii.gz
#     t_4603_a_1.nii.gz
#     t_4671_a_1.nii.gz
#     t_4717_a_1.nii.gz
#     t_4772_a_1.nii.gz
#     t_4786_a_1.nii.gz
#     t_4875_a_1.nii.gz
#     t_4885_a_1.nii.gz
#     t_488_a_1.nii.gz
#     t_491_a_1.nii.gz
#     t_4944_a_1.nii.gz
#     t_4988_a_1.nii.gz
#     t_5000_b_1.nii.gz
#     t_501_a_1.nii.gz
#     t_5030_a_1.nii.gz
#     t_5074_a_1.nii.gz
#     t_50_a_1.nii.gz
#     t_511_a_1.nii.gz
#     t_512_a_1.nii.gz
#     t_5190_a_1.nii.gz
#     t_5235_a_1.nii.gz
#     t_5257_a_1.nii.gz
#     t_5261_a_1.nii.gz
#     t_5266_a_1.nii.gz
#     t_5356_a_1.nii.gz
#     t_5359_a_1.nii.gz
#     t_5395_a_1.nii.gz
#     t_5417_a_2.nii.gz
#     t_5437_a_1.nii.gz
#     t_5495_a_1.nii.gz
#     t_5507_b_1.nii.gz
#     t_5594_a_1.nii.gz
#     t_5597_a_1.nii.gz
#     t_560_a_1.nii.gz
#     t_5618_a_1.nii.gz
#     t_5626_a_1.nii.gz
#     t_5682_a_1.nii.gz
#     t_5695_a_1.nii.gz
#     t_5725_a_1.nii.gz
#     t_573_a_1.nii.gz
#     t_5754_a_1.nii.gz
#     t_5815_a_1.nii.gz
#     t_5816_a_1.nii.gz
#     t_5817_b_1.nii.gz
#     t_5885_a_1.nii.gz
#     t_5890_a_1.nii.gz
#     t_5989_a_1.nii.gz
#     t_5991_a_1.nii.gz
#     t_5992_a_1.nii.gz
#     t_5997_a_1.nii.gz
#     t_6035_b_1.nii.gz
#     t_6047_b_1.nii.gz
#     t_604_a_2.nii.gz
#     t_6072_a_1.nii.gz
#     t_6130_b_1.nii.gz
#     t_6132_a_1.nii.gz
#     t_6138_a_1.nii.gz
#     t_6175_a_1.nii.gz
#     t_621_a_1.nii.gz
#     t_6274_a_1.nii.gz
#     t_6283_a_1.nii.gz
#     t_6321_b_1.nii.gz
#     t_6328_a_1.nii.gz
#     t_6359_a_1.nii.gz
#     t_6375_a_1.nii.gz
#     t_6380_a_1.nii.gz
#     t_641_a_1.nii.gz
#     t_6440_a_1.nii.gz
#     t_6443_a_1.nii.gz
#     t_6454_a_1.nii.gz
#     t_6482_a_2.nii.gz
#     t_6487_a_1.nii.gz
#     t_6489_a_1.nii.gz
#     t_6581_a_1.nii.gz
#     t_662_c_1.nii.gz
#     t_6636_a_1.nii.gz
#     t_6669_a_1.nii.gz
#     t_6672_a_1.nii.gz
#     t_6688_b_1.nii.gz
#     t_6690_a_1.nii.gz
#     t_66_a_1.nii.gz
#     t_6709_a_1.nii.gz
#     t_6759_a_1.nii.gz
#     t_6794_a_1.nii.gz
#     t_6797_a_1.nii.gz
#     t_6835_b_1.nii.gz
#     t_6898_a_1.nii.gz
#     t_6902_b_1.nii.gz
#     t_6907_a_1.nii.gz
#     t_6918_a_1.nii.gz
#     t_6932_a_1.nii.gz
#     t_6960_a_1.nii.gz
#     t_7002_a_1.nii.gz
#     t_7054_a_1.nii.gz
#     t_7058_a_1.nii.gz
#     t_7061_b_1.nii.gz
#     t_7079_a_1.nii.gz
#     t_7085_a_1.nii.gz
#     t_7117_a_1.nii.gz
#     t_712_a_1.nii.gz
#     t_7131_a_1.nii.gz
#     t_7157_a_1.nii.gz
#     t_7220_a_1.nii.gz
#     t_7223_a_1.nii.gz
#     t_722_a_1.nii.gz
#     t_7236_a_1.nii.gz
#     t_7240_a_1.nii.gz
#     t_7259_a_1.nii.gz
#     t_7262_a_1.nii.gz
#     t_7265_a_1.nii.gz
#     t_727_a_1.nii.gz
#     t_7288_a_1.nii.gz
#     t_7293_a_1.nii.gz
#     t_7328_a_1.nii.gz
#     t_7329_a_1.nii.gz
#     t_7346_a_1.nii.gz
#     t_7368_a_1.nii.gz
#     t_742_a_1.nii.gz
#     t_745_a_1.nii.gz
#     t_7481_a_1.nii.gz
#     t_7487_a_1.nii.gz
#     t_7530_a_1.nii.gz
#     t_754_a_1.nii.gz
#     t_7602_a_1.nii.gz
#     t_7604_a_1.nii.gz
#     t_7610_b_1.nii.gz
#     t_7644_a_1.nii.gz
#     t_7650_a_1.nii.gz
#     t_7667_a_1.nii.gz
#     t_7673_a_1.nii.gz
#     t_7692_a_1.nii.gz
#     t_7701_a_1.nii.gz
#     t_7738_a_1.nii.gz
#     t_7756_a_1.nii.gz
#     t_7804_a_1.nii.gz
#     t_7815_a_1.nii.gz
#     t_7834_b_1.nii.gz
#     t_7841_a_1.nii.gz
#     t_7843_a_1.nii.gz
#     t_7845_b_1.nii.gz
#     t_784_a_1.nii.gz
#     t_7883_a_1.nii.gz
#     t_790_a_1.nii.gz
#     t_7912_a_1.nii.gz
#     t_7959_a_1.nii.gz
#     t_7970_a_1.nii.gz
#     t_7974_a_1.nii.gz
#     t_8018_a_1.nii.gz
#     t_8030_a_1.nii.gz
#     t_8055_a_1.nii.gz
#     t_807_a_1.nii.gz
#     t_8093_a_1.nii.gz
#     t_8097_a_2.nii.gz
#     t_8101_b_1.nii.gz
#     t_8112_a_1.nii.gz
#     t_8132_a_1.nii.gz
#     t_8148_a_1.nii.gz
#     t_8222_a_1.nii.gz
#     t_8234_a_1.nii.gz
#     t_8270_a_1.nii.gz
#     t_8278_a_1.nii.gz
#     t_8280_a_1.nii.gz
#     t_8288_b_1.nii.gz
#     t_8300_a_1.nii.gz
#     t_8323_a_1.nii.gz
#     t_8330_a_1.nii.gz
#     t_8340_a_1.nii.gz
#     t_8342_a_1.nii.gz
#     t_838_a_1.nii.gz
#     t_8392_a_1.nii.gz
#     t_8418_a_1.nii.gz
#     t_8420_d_1.nii.gz
#     t_842_a_1.nii.gz
#     t_8443_a_1.nii.gz
#     t_8458_a_1.nii.gz
#     t_8464_a_1.nii.gz
#     t_8474_a_1.nii.gz
#     t_84_a_1.nii.gz
#     t_8535_a_1.nii.gz
#     t_8549_c_1.nii.gz
#     t_8554_a_1.nii.gz
#     t_8556_a_1.nii.gz
#     t_8565_a_1.nii.gz
#     t_8601_a_1.nii.gz
#     t_860_a_1.nii.gz
#     t_8673_a_1.nii.gz
#     t_8698_b_1.nii.gz
#     t_8756_a_1.nii.gz
#     t_8773_a_1.nii.gz
#     t_8779_a_1.nii.gz
#     t_8785_a_1.nii.gz
#     t_8837_a_1.nii.gz
#     t_8844_a_1.nii.gz
#     t_8871_a_1.nii.gz
#     t_8886_a_1.nii.gz
#     t_8890_a_1.nii.gz
#     t_8898_a_1.nii.gz
#     t_8912_a_1.nii.gz
#     t_892_a_1.nii.gz
#     t_8973_a_1.nii.gz
#     t_8974_a_1.nii.gz
#     t_8981_a_1.nii.gz
#     t_9015_a_1.nii.gz
#     t_9041_a_1.nii.gz
#     t_9055_a_1.nii.gz
#     t_9059_a_1.nii.gz
#     t_9060_a_1.nii.gz
#     t_9106_a_1.nii.gz
#     t_9131_a_1.nii.gz
#     t_9158_a_1.nii.gz
#     t_916_a_1.nii.gz
#     t_9184_a_1.nii.gz
#     t_9193_a_1.nii.gz
#     t_921_a_1.nii.gz
#     t_9245_a_1.nii.gz
#     t_924_a_1.nii.gz
#     t_926_a_1.nii.gz
#     t_9329_a_1.nii.gz
#     t_9346_a_1.nii.gz
#     t_9386_a_1.nii.gz
#     t_9484_a_1.nii.gz
#     t_9507_a_1.nii.gz
#     t_9521_a_1.nii.gz
#     t_9559_a_1.nii.gz
#     t_9572_a_1.nii.gz
#     t_9579_c_1.nii.gz
#     t_9616_a_1.nii.gz
#     t_9630_a_1.nii.gz
#     t_966_a_1.nii.gz
#     t_9687_a_1.nii.gz
#     t_9702_a_1.nii.gz
#     t_9714_a_1.nii.gz
#     t_9756_a_1.nii.gz
#     t_9763_a_1.nii.gz
#     t_9806_a_1.nii.gz
#     t_9820_a_1.nii.gz
#     t_9888_a_1.nii.gz
#     t_992_a_1.nii.gz
#     t_9941_a_1.nii.gz
#     t_9970_a_1.nii.gz
#     t_9972_a_1.nii.gz
#
# Summary:
# Total files in image folder: 770
# Total files in mask folder: 770
# Files only in image folder: 770
# Files only in mask folder: 770
# Common files: 0

# %%
def explore_folder_mismatch(img_folder, mask_folder):
    """
    Compares the contents of two folders and identifies mismatched files after removing `_0000` from image filenames.

    Args:
        img_folder (str): Path to the folder containing images.
        mask_folder (str): Path to the folder containing masks.

    Returns:
        None
    """
    # List files in both folders
    img_files = sorted(os.listdir(img_folder))
    mask_files = sorted(os.listdir(mask_folder))

    # Remove '_0000' suffix from image filenames
    img_files_modified = [file.replace("_0000", "") for file in img_files]

    # Convert file lists to sets
    img_set = set(img_files_modified)
    mask_set = set(mask_files)

    # Identify mismatches
    only_in_img = img_set - mask_set
    only_in_mask = mask_set - img_set
    common_files = img_set & mask_set

    # Print mismatched files
    print("Files only in image folder (after removing '_0000'):")
    for file in only_in_img:
        print(f"  {file}")
    print("\nFiles only in mask folder:")
    for file in only_in_mask:
        print(f"  {file}")
    print("\nCommon files:")
    for file in common_files:
        print(f"  {file}")

    # Summary
    print("\nSummary:")
    print(f"Total files in image folder (modified): {len(img_files_modified)}")
    print(f"Total files in mask folder: {len(mask_files)}")
    print(f"Files only in image folder: {len(only_in_img)}")
    print(f"Files only in mask folder: {len(only_in_mask)}")
    print(f"Common files: {len(common_files)}")


# Example Usage
img_folder = "/data/bruce/unet/Dataset002_AnychestTry/imagesTr"
mask_folder = "/data/bruce/unet/Dataset002_AnychestTry/labelsTr"
explore_folder_mismatch(img_folder, mask_folder)
# Out:
# Files only in image folder (after removing '_0000'):
#
# Files only in mask folder:
#
# Common files:
#   t_7293_a_1.nii.gz
#   t_12952_a_1.nii.gz
#   t_4603_a_1.nii.gz
#   t_5190_a_1.nii.gz
#   t_13720_a_1.nii.gz
#   t_15906_a_1.nii.gz
#   t_16666_a_1.nii.gz
#   t_10233_a_1.nii.gz
#   t_14728_a_1.nii.gz
#   t_9015_a_1.nii.gz
#   t_9714_a_1.nii.gz
#   t_14369_a_1.nii.gz
#   t_17367_a_1.nii.gz
#   t_18196_a_1.nii.gz
#   t_17197_a_1.nii.gz
#   t_15010_a_1.nii.gz
#   t_18730_a_1.nii.gz
#   t_18055_a_1.nii.gz
#   t_2296_a_1.nii.gz
#   t_2478_a_1.nii.gz
#   t_6440_a_1.nii.gz
#   t_13244_a_1.nii.gz
#   t_1385_a_1.nii.gz
#   t_13711_a_1.nii.gz
#   t_3799_a_1.nii.gz
#   t_4023_c_1.nii.gz
#   t_5359_a_1.nii.gz
#   t_17237_a_1.nii.gz
#   t_11303_a_1.nii.gz
#   t_6138_a_1.nii.gz
#   t_8785_a_1.nii.gz
#   t_10152_a_1.nii.gz
#   t_9820_a_1.nii.gz
#   t_7262_a_1.nii.gz
#   t_3686_a_1.nii.gz
#   t_16354_a_1.nii.gz
#   t_15965_a_1.nii.gz
#   t_8973_a_1.nii.gz
#   t_5816_a_1.nii.gz
#   t_5885_a_1.nii.gz
#   t_4514_b_1.nii.gz
#   t_184_a_1.nii.gz
#   t_7673_a_1.nii.gz
#   t_16107_a_1.nii.gz
#   t_11372_a_1.nii.gz
#   t_3145_a_1.nii.gz
#   t_7061_b_1.nii.gz
#   t_13339_a_1.nii.gz
#   t_6380_a_1.nii.gz
#   t_16525_a_1.nii.gz
#   t_15565_a_1.nii.gz
#   t_9059_a_1.nii.gz
#   t_8420_d_1.nii.gz
#   t_16384_a_1.nii.gz
#   t_1329_a_1.nii.gz
#   t_1545_a_1.nii.gz
#   t_14084_a_1.nii.gz
#   t_1700_a_1.nii.gz
#   t_11816_a_1.nii.gz
#   t_277_a_1.nii.gz
#   t_9346_a_1.nii.gz
#   t_1270_a_1.nii.gz
#   t_5992_a_1.nii.gz
#   t_11805_a_1.nii.gz
#   t_13714_a_1.nii.gz
#   t_8097_a_2.nii.gz
#   t_17268_a_1.nii.gz
#   t_8698_b_1.nii.gz
#   t_6035_b_1.nii.gz
#   t_3210_a_1.nii.gz
#   t_14142_a_1.nii.gz
#   t_14571_a_1.nii.gz
#   t_13077_a_1.nii.gz
#   t_1542_a_1.nii.gz
#   t_8565_a_1.nii.gz
#   t_15346_a_1.nii.gz
#   t_11010_a_1.nii.gz
#   t_174_a_1.nii.gz
#   t_8148_a_1.nii.gz
#   t_13826_a_1.nii.gz
#   t_8300_a_1.nii.gz
#   t_16896_a_1.nii.gz
#   t_9888_a_1.nii.gz
#   t_5682_a_1.nii.gz
#   t_2526_a_1.nii.gz
#   t_491_a_1.nii.gz
#   t_17293_a_1.nii.gz
#   t_16074_a_1.nii.gz
#   t_19915_a_1.nii.gz
#   t_12455_b_1.nii.gz
#   t_13147_a_1.nii.gz
#   t_18847_a_1.nii.gz
#   t_5618_a_1.nii.gz
#   t_12146_a_1.nii.gz
#   t_1600_a_1.nii.gz
#   t_12741_a_1.nii.gz
#   t_11594_a_1.nii.gz
#   t_3928_a_1.nii.gz
#   t_14000_a_1.nii.gz
#   t_13375_a_1.nii.gz
#   t_10483_a_1.nii.gz
#   t_14926_a_1.nii.gz
#   t_17421_a_1.nii.gz
#   t_17959_a_1.nii.gz
#   t_11963_a_1.nii.gz
#   t_13749_a_1.nii.gz
#   t_14876_a_1.nii.gz
#   t_4522_a_1.nii.gz
#   t_892_a_1.nii.gz
#   t_12563_b_1.nii.gz
#   t_3092_a_1.nii.gz
#   t_19245_a_1.nii.gz
#   t_6487_a_1.nii.gz
#   t_18798_a_1.nii.gz
#   t_15895_a_1.nii.gz
#   t_12699_a_1.nii.gz
#   t_742_a_1.nii.gz
#   t_17128_a_1.nii.gz
#   t_4944_a_1.nii.gz
#   t_1935_a_1.nii.gz
#   t_1516_b_1.nii.gz
#   t_7610_b_1.nii.gz
#   t_9702_a_1.nii.gz
#   t_11609_a_1.nii.gz
#   t_488_a_1.nii.gz
#   t_5074_a_1.nii.gz
#   t_8554_a_1.nii.gz
#   t_7650_a_1.nii.gz
#   t_10671_a_1.nii.gz
#   t_3723_a_1.nii.gz
#   t_19919_a_1.nii.gz
#   t_7487_a_1.nii.gz
#   t_1120_a_1.nii.gz
#   t_842_a_1.nii.gz
#   t_10591_a_1.nii.gz
#   t_4544_a_1.nii.gz
#   t_12627_a_1.nii.gz
#   t_5356_a_1.nii.gz
#   t_7259_a_1.nii.gz
#   t_8474_a_1.nii.gz
#   t_4489_a_1.nii.gz
#   t_7738_a_1.nii.gz
#   t_18612_a_1.nii.gz
#   t_9572_a_1.nii.gz
#   t_1378_a_1.nii.gz
#   t_14214_c_1.nii.gz
#   t_10311_a_1.nii.gz
#   t_10494_a_1.nii.gz
#   t_4379_a_1.nii.gz
#   t_19132_a_1.nii.gz
#   t_8556_a_1.nii.gz
#   t_921_a_1.nii.gz
#   t_18_a_1.nii.gz
#   t_10936_a_1.nii.gz
#   t_11952_a_1.nii.gz
#   t_9941_a_1.nii.gz
#   t_9756_a_1.nii.gz
#   t_4875_a_1.nii.gz
#   t_11186_b_1.nii.gz
#   t_10216_a_1.nii.gz
#   t_15292_a_1.nii.gz
#   t_14393_a_1.nii.gz
#   t_3787_a_1.nii.gz
#   t_66_a_1.nii.gz
#   t_7329_a_1.nii.gz
#   t_7604_a_1.nii.gz
#   t_7970_a_1.nii.gz
#   t_9106_a_1.nii.gz
#   t_19761_a_1.nii.gz
#   t_19401_a_1.nii.gz
#   t_11344_b_1.nii.gz
#   t_1267_a_1.nii.gz
#   t_6321_b_1.nii.gz
#   t_3286_a_1.nii.gz
#   t_10663_a_1.nii.gz
#   t_10731_a_1.nii.gz
#   t_2562_b_1.nii.gz
#   t_5815_a_1.nii.gz
#   t_501_a_1.nii.gz
#   t_13304_a_1.nii.gz
#   t_15137_a_1.nii.gz
#   t_6898_a_1.nii.gz
#   t_12551_a_1.nii.gz
#   t_9184_a_1.nii.gz
#   t_12040_a_1.nii.gz
#   t_15248_a_1.nii.gz
#   t_12372_a_1.nii.gz
#   t_16200_a_1.nii.gz
#   t_11115_a_1.nii.gz
#   t_5417_a_2.nii.gz
#   t_18353_a_1.nii.gz
#   t_4377_b_1.nii.gz
#   t_926_a_1.nii.gz
#   t_9806_a_1.nii.gz
#   t_131_a_1.nii.gz
#   t_10062_a_1.nii.gz
#   t_16254_a_1.nii.gz
#   t_9763_a_1.nii.gz
#   t_12717_a_1.nii.gz
#   t_12572_a_1.nii.gz
#   t_7843_a_1.nii.gz
#   t_9616_a_1.nii.gz
#   t_3138_a_1.nii.gz
#   t_14519_a_1.nii.gz
#   t_712_a_1.nii.gz
#   t_18486_a_1.nii.gz
#   t_10208_a_1.nii.gz
#   t_15430_a_1.nii.gz
#   t_18545_a_1.nii.gz
#   t_1507_a_1.nii.gz
#   t_18640_a_1.nii.gz
#   t_4467_a_1.nii.gz
#   t_13983_a_1.nii.gz
#   t_3080_a_1.nii.gz
#   t_16137_a_1.nii.gz
#   t_15799_a_1.nii.gz
#   t_18132_a_1.nii.gz
#   t_16010_a_1.nii.gz
#   t_18587_a_1.nii.gz
#   t_7223_a_1.nii.gz
#   t_5495_a_1.nii.gz
#   t_7368_a_1.nii.gz
#   t_1805_a_1.nii.gz
#   t_6283_a_1.nii.gz
#   t_10172_a_1.nii.gz
#   t_6794_a_1.nii.gz
#   t_12424_a_1.nii.gz
#   t_17324_a_1.nii.gz
#   t_10533_a_1.nii.gz
#   t_12849_a_1.nii.gz
#   t_18135_a_1.nii.gz
#   t_14431_a_1.nii.gz
#   t_12127_a_1.nii.gz
#   t_5754_a_1.nii.gz
#   t_6636_a_1.nii.gz
#   t_9559_a_1.nii.gz
#   t_7131_a_1.nii.gz
#   t_17453_c_1.nii.gz
#   t_3436_a_1.nii.gz
#   t_17148_a_1.nii.gz
#   t_19705_a_1.nii.gz
#   t_2275_a_1.nii.gz
#   t_18818_a_1.nii.gz
#   t_18154_a_1.nii.gz
#   t_19742_a_1.nii.gz
#   t_19692_a_1.nii.gz
#   t_784_a_1.nii.gz
#   t_12711_a_1.nii.gz
#   t_8288_b_1.nii.gz
#   t_6489_a_1.nii.gz
#   t_8280_a_1.nii.gz
#   t_662_c_1.nii.gz
#   t_10214_a_1.nii.gz
#   t_13639_a_1.nii.gz
#   t_84_a_1.nii.gz
#   t_454_a_1.nii.gz
#   t_8392_a_1.nii.gz
#   t_16606_a_1.nii.gz
#   t_5626_a_1.nii.gz
#   t_17874_a_1.nii.gz
#   t_440_b_1.nii.gz
#   t_15467_a_1.nii.gz
#   t_14601_a_1.nii.gz
#   t_3653_e_1.nii.gz
#   t_12426_a_1.nii.gz
#   t_3769_a_1.nii.gz
#   t_6835_b_1.nii.gz
#   t_9386_a_1.nii.gz
#   t_14987_a_1.nii.gz
#   t_8673_a_1.nii.gz
#   t_7815_a_1.nii.gz
#   t_8458_a_1.nii.gz
#   t_11469_a_1.nii.gz
#   t_16891_a_1.nii.gz
#   t_15358_a_1.nii.gz
#   t_6454_a_1.nii.gz
#   t_4786_a_1.nii.gz
#   t_16652_a_1.nii.gz
#   t_12520_a_1.nii.gz
#   t_9193_a_1.nii.gz
#   t_15645_a_1.nii.gz
#   t_11880_c_1.nii.gz
#   t_18754_a_1.nii.gz
#   t_10177_a_1.nii.gz
#   t_14376_a_2.nii.gz
#   t_9131_a_1.nii.gz
#   t_10860_a_1.nii.gz
#   t_10694_a_1.nii.gz
#   t_4592_a_1.nii.gz
#   t_14281_a_1.nii.gz
#   t_15062_a_1.nii.gz
#   t_8234_a_1.nii.gz
#   t_9521_a_1.nii.gz
#   t_16058_a_1.nii.gz
#   t_12912_a_1.nii.gz
#   t_9687_a_1.nii.gz
#   t_10592_a_1.nii.gz
#   t_14760_a_1.nii.gz
#   t_1322_a_1.nii.gz
#   t_15918_a_1.nii.gz
#   t_1901_a_1.nii.gz
#   t_19588_b_1.nii.gz
#   t_13300_a_1.nii.gz
#   t_18187_a_1.nii.gz
#   t_3052_a_1.nii.gz
#   t_4885_a_1.nii.gz
#   t_573_a_1.nii.gz
#   t_8779_a_1.nii.gz
#   t_2188_a_1.nii.gz
#   t_7054_a_1.nii.gz
#   t_4306_a_1.nii.gz
#   t_8912_a_1.nii.gz
#   t_2167_a_1.nii.gz
#   t_12000_a_1.nii.gz
#   t_1054_a_1.nii.gz
#   t_13118_a_1.nii.gz
#   t_5991_a_1.nii.gz
#   t_2823_a_1.nii.gz
#   t_18253_a_1.nii.gz
#   t_19797_a_1.nii.gz
#   t_8018_a_1.nii.gz
#   t_11834_a_1.nii.gz
#   t_13620_a_1.nii.gz
#   t_15274_a_1.nii.gz
#   t_9041_a_1.nii.gz
#   t_8093_a_1.nii.gz
#   t_9060_a_1.nii.gz
#   t_3173_b_1.nii.gz
#   t_18167_a_1.nii.gz
#   t_2990_a_1.nii.gz
#   t_5266_a_1.nii.gz
#   t_560_a_1.nii.gz
#   t_8278_a_1.nii.gz
#   t_10923_a_1.nii.gz
#   t_11126_a_1.nii.gz
#   t_6690_a_1.nii.gz
#   t_10473_b_1.nii.gz
#   t_11260_a_2.nii.gz
#   t_1734_a_1.nii.gz
#   t_14891_a_1.nii.gz
#   t_4671_a_1.nii.gz
#   t_10026_a_1.nii.gz
#   t_291_a_2.nii.gz
#   t_2306_a_1.nii.gz
#   t_3038_b_1.nii.gz
#   t_10039_a_1.nii.gz
#   t_18027_a_1.nii.gz
#   t_18098_a_1.nii.gz
#   t_17635_b_1.nii.gz
#   t_7085_a_1.nii.gz
#   t_2383_a_1.nii.gz
#   t_13692_a_1.nii.gz
#   t_13914_a_1.nii.gz
#   t_2888_a_1.nii.gz
#   t_5695_a_1.nii.gz
#   t_11602_a_1.nii.gz
#   t_838_a_1.nii.gz
#   t_19539_a_1.nii.gz
#   t_18997_a_1.nii.gz
#   t_5997_a_1.nii.gz
#   t_18600_a_1.nii.gz
#   t_16124_a_1.nii.gz
#   t_2936_a_1.nii.gz
#   t_6709_a_1.nii.gz
#   t_19875_b_1.nii.gz
#   t_18242_a_1.nii.gz
#   t_15508_a_1.nii.gz
#   t_3565_a_1.nii.gz
#   t_10271_a_1.nii.gz
#   t_11652_a_1.nii.gz
#   t_10438_a_1.nii.gz
#   t_14166_b_1.nii.gz
#   t_11658_a_1.nii.gz
#   t_12489_a_1.nii.gz
#   t_3710_a_1.nii.gz
#   t_7265_a_1.nii.gz
#   t_13942_a_1.nii.gz
#   t_1871_a_1.nii.gz
#   t_11946_a_1.nii.gz
#   t_14979_a_1.nii.gz
#   t_5395_a_1.nii.gz
#   t_11485_b_1.nii.gz
#   t_7288_a_1.nii.gz
#   t_15038_a_1.nii.gz
#   t_13599_a_1.nii.gz
#   t_1753_a_1.nii.gz
#   t_237_b_1.nii.gz
#   t_511_a_1.nii.gz
#   t_13888_a_1.nii.gz
#   t_8844_a_1.nii.gz
#   t_10845_a_1.nii.gz
#   t_8340_a_1.nii.gz
#   t_17869_a_1.nii.gz
#   t_19391_a_1.nii.gz
#   t_11038_a_1.nii.gz
#   t_19317_a_1.nii.gz
#   t_1706_d_1.nii.gz
#   t_8101_b_1.nii.gz
#   t_19191_b_1.nii.gz
#   t_1987_b_1.nii.gz
#   t_2574_b_1.nii.gz
#   t_3522_a_1.nii.gz
#   t_4988_a_1.nii.gz
#   t_11047_a_1.nii.gz
#   t_11960_a_1.nii.gz
#   t_2315_a_1.nii.gz
#   t_7912_a_1.nii.gz
#   t_18428_a_1.nii.gz
#   t_10908_a_1.nii.gz
#   t_8601_a_1.nii.gz
#   t_4433_a_1.nii.gz
#   t_1900_a_1.nii.gz
#   t_1958_a_1.nii.gz
#   t_15257_a_1.nii.gz
#   t_16949_a_1.nii.gz
#   t_2488_a_1.nii.gz
#   t_8342_a_1.nii.gz
#   t_3737_a_1.nii.gz
#   t_3174_a_1.nii.gz
#   t_4143_a_1.nii.gz
#   t_1018_a_2.nii.gz
#   t_8443_a_1.nii.gz
#   t_3003_a_1.nii.gz
#   t_5507_b_1.nii.gz
#   t_15078_a_1.nii.gz
#   t_15131_a_1.nii.gz
#   t_12361_a_1.nii.gz
#   t_11551_a_1.nii.gz
#   t_2319_a_1.nii.gz
#   t_3403_a_1.nii.gz
#   t_17315_a_1.nii.gz
#   t_12786_a_1.nii.gz
#   t_18956_a_1.nii.gz
#   t_13178_a_1.nii.gz
#   t_16831_a_1.nii.gz
#   t_2726_a_1.nii.gz
#   t_18757_a_1.nii.gz
#   t_10803_a_1.nii.gz
#   t_15494_a_1.nii.gz
#   t_19205_a_1.nii.gz
#   t_722_a_1.nii.gz
#   t_745_a_1.nii.gz
#   t_19524_a_1.nii.gz
#   t_4286_a_1.nii.gz
#   t_11315_g_1.nii.gz
#   t_19578_a_1.nii.gz
#   t_5000_b_1.nii.gz
#   t_16155_a_1.nii.gz
#   t_9329_a_1.nii.gz
#   t_16622_a_1.nii.gz
#   t_2928_a_1.nii.gz
#   t_3779_a_1.nii.gz
#   t_15502_a_1.nii.gz
#   t_2224_a_1.nii.gz
#   t_12077_a_1.nii.gz
#   t_2663_a_1.nii.gz
#   t_13213_a_1.nii.gz
#   t_3880_a_1.nii.gz
#   t_1440_a_1.nii.gz
#   t_9484_a_1.nii.gz
#   t_8773_a_1.nii.gz
#   t_16390_a_1.nii.gz
#   t_4172_a_1.nii.gz
#   t_7804_a_1.nii.gz
#   t_19279_c_1.nii.gz
#   t_13970_a_1.nii.gz
#   t_6132_a_1.nii.gz
#   t_6175_a_1.nii.gz
#   t_4029_a_1.nii.gz
#   t_1214_a_1.nii.gz
#   t_7845_b_1.nii.gz
#   t_6072_a_1.nii.gz
#   t_10981_b_1.nii.gz
#   t_11850_a_1.nii.gz
#   t_14832_a_1.nii.gz
#   t_7602_a_1.nii.gz
#   t_9507_a_1.nii.gz
#   t_2898_a_1.nii.gz
#   t_8898_a_1.nii.gz
#   t_17514_a_1.nii.gz
#   t_14947_c_1.nii.gz
#   t_17631_a_1.nii.gz
#   t_19219_b_1.nii.gz
#   t_15856_a_1.nii.gz
#   t_7834_b_1.nii.gz
#   t_13151_a_1.nii.gz
#   t_6907_a_1.nii.gz
#   t_2541_b_1.nii.gz
#   t_14984_a_1.nii.gz
#   t_2620_a_1.nii.gz
#   t_6482_a_2.nii.gz
#   t_754_a_1.nii.gz
#   t_17924_a_1.nii.gz
#   t_11174_a_1.nii.gz
#   t_10393_a_1.nii.gz
#   t_16718_a_1.nii.gz
#   t_6797_a_1.nii.gz
#   t_17708_a_1.nii.gz
#   t_50_a_1.nii.gz
#   t_8055_a_1.nii.gz
#   t_16132_a_1.nii.gz
#   t_1205_a_1.nii.gz
#   t_18341_a_1.nii.gz
#   t_7328_a_1.nii.gz
#   t_16235_a_1.nii.gz
#   t_6932_a_1.nii.gz
#   t_14763_a_1.nii.gz
#   t_16070_a_1.nii.gz
#   t_641_a_1.nii.gz
#   t_8222_a_1.nii.gz
#   t_12387_a_1.nii.gz
#   t_8756_a_1.nii.gz
#   t_3796_a_1.nii.gz
#   t_8112_a_1.nii.gz
#   t_8464_a_1.nii.gz
#   t_7117_a_1.nii.gz
#   t_17813_a_1.nii.gz
#   t_9972_a_1.nii.gz
#   t_18693_a_1.nii.gz
#   t_5437_a_1.nii.gz
#   t_11388_a_1.nii.gz
#   t_19627_a_1.nii.gz
#   t_18636_a_1.nii.gz
#   t_14648_a_1.nii.gz
#   t_15488_a_1.nii.gz
#   t_2160_a_1.nii.gz
#   t_2854_a_1.nii.gz
#   t_1086_a_1.nii.gz
#   t_14401_a_1.nii.gz
#   t_3268_a_1.nii.gz
#   t_7346_a_1.nii.gz
#   t_19874_a_1.nii.gz
#   t_8323_a_1.nii.gz
#   t_7756_a_1.nii.gz
#   t_6375_a_1.nii.gz
#   t_19482_a_1.nii.gz
#   t_604_a_2.nii.gz
#   t_11797_a_1.nii.gz
#   t_15206_a_1.nii.gz
#   t_17623_a_1.nii.gz
#   t_17592_a_1.nii.gz
#   t_17999_c_1.nii.gz
#   t_19999_a_1.nii.gz
#   t_11273_a_1.nii.gz
#   t_1229_a_1.nii.gz
#   t_8981_a_1.nii.gz
#   t_19109_a_1.nii.gz
#   t_19529_a_1.nii.gz
#   t_3793_a_1.nii.gz
#   t_19909_a_1.nii.gz
#   t_2529_a_1.nii.gz
#   t_1395_a_1.nii.gz
#   t_13113_a_1.nii.gz
#   t_19093_b_1.nii.gz
#   t_3018_a_1.nii.gz
#   t_3603_a_1.nii.gz
#   t_5261_a_1.nii.gz
#   t_7058_a_1.nii.gz
#   t_11281_a_1.nii.gz
#   t_13380_a_1.nii.gz
#   t_16619_a_1.nii.gz
#   t_19781_a_1.nii.gz
#   t_2025_a_1.nii.gz
#   t_5817_b_1.nii.gz
#   t_6359_a_1.nii.gz
#   t_6672_a_1.nii.gz
#   t_350_a_1.nii.gz
#   t_16741_a_1.nii.gz
#   t_15857_a_1.nii.gz
#   t_4436_b_1.nii.gz
#   t_7481_a_1.nii.gz
#   t_17778_a_1.nii.gz
#   t_10782_a_1.nii.gz
#   t_11613_a_1.nii.gz
#   t_5594_a_1.nii.gz
#   t_15632_a_1.nii.gz
#   t_8418_a_1.nii.gz
#   t_112_a_1.nii.gz
#   t_6902_b_1.nii.gz
#   t_7883_a_1.nii.gz
#   t_3772_a_1.nii.gz
#   t_5257_a_1.nii.gz
#   t_15629_a_1.nii.gz
#   t_18983_a_1.nii.gz
#   t_4504_b_1.nii.gz
#   t_6918_a_1.nii.gz
#   t_6328_a_1.nii.gz
#   t_7959_a_1.nii.gz
#   t_18477_a_1.nii.gz
#   t_17202_a_1.nii.gz
#   t_17562_a_1.nii.gz
#   t_11026_a_1.nii.gz
#   t_3583_a_1.nii.gz
#   t_13301_b_1.nii.gz
#   t_8890_a_1.nii.gz
#   t_4429_a_1.nii.gz
#   t_5030_a_1.nii.gz
#   t_11132_a_1.nii.gz
#   t_12595_a_1.nii.gz
#   t_14837_a_1.nii.gz
#   t_14489_a_1.nii.gz
#   t_10987_a_1.nii.gz
#   t_15065_a_1.nii.gz
#   t_13202_c_1.nii.gz
#   t_5890_a_1.nii.gz
#   t_11453_a_1.nii.gz
#   t_4717_a_1.nii.gz
#   t_288_a_1.nii.gz
#   t_19173_a_1.nii.gz
#   t_2262_a_1.nii.gz
#   t_16761_a_1.nii.gz
#   t_18746_a_1.nii.gz
#   t_4314_a_1.nii.gz
#   t_16547_a_1.nii.gz
#   t_1792_a_1.nii.gz
#   t_1522_a_1.nii.gz
#   t_5235_a_1.nii.gz
#   t_18840_b_1.nii.gz
#   t_13518_a_1.nii.gz
#   t_6274_a_1.nii.gz
#   t_12631_a_1.nii.gz
#   t_14323_a_1.nii.gz
#   t_4051_a_1.nii.gz
#   t_16790_a_1.nii.gz
#   t_3088_a_1.nii.gz
#   t_7974_a_1.nii.gz
#   t_1437_b_1.nii.gz
#   t_7530_a_1.nii.gz
#   t_11476_a_1.nii.gz
#   t_15940_b_1.nii.gz
#   t_18717_e_1.nii.gz
#   t_14554_a_1.nii.gz
#   t_13892_a_1.nii.gz
#   t_15240_a_1.nii.gz
#   t_924_a_1.nii.gz
#   t_17998_a_1.nii.gz
#   t_2704_a_1.nii.gz
#   t_19852_a_1.nii.gz
#   t_6759_a_1.nii.gz
#   t_17553_a_1.nii.gz
#   t_18753_a_1.nii.gz
#   t_5597_a_1.nii.gz
#   t_11066_a_1.nii.gz
#   t_11432_a_1.nii.gz
#   t_13036_a_1.nii.gz
#   t_7236_a_1.nii.gz
#   t_11421_a_1.nii.gz
#   t_19274_a_1.nii.gz
#   t_7240_a_1.nii.gz
#   t_8974_a_1.nii.gz
#   t_6047_b_1.nii.gz
#   t_807_a_1.nii.gz
#   t_17276_a_1.nii.gz
#   t_18616_a_1.nii.gz
#   t_5725_a_1.nii.gz
#   t_16088_a_1.nii.gz
#   t_13276_a_1.nii.gz
#   t_11867_a_1.nii.gz
#   t_790_a_1.nii.gz
#   t_6669_a_1.nii.gz
#   t_13824_b_1.nii.gz
#   t_17426_a_1.nii.gz
#   t_8132_a_1.nii.gz
#   t_3143_a_1.nii.gz
#   t_7644_a_1.nii.gz
#   t_2689_a_1.nii.gz
#   t_2987_a_1.nii.gz
#   t_18821_a_1.nii.gz
#   t_10549_a_1.nii.gz
#   t_14632_a_1.nii.gz
#   t_15156_a_1.nii.gz
#   t_4199_a_1.nii.gz
#   t_14746_a_1.nii.gz
#   t_19772_a_1.nii.gz
#   t_2408_a_1.nii.gz
#   t_11956_a_1.nii.gz
#   t_2481_a_1.nii.gz
#   t_18163_a_1.nii.gz
#   t_7220_a_1.nii.gz
#   t_15157_a_1.nii.gz
#   t_19962_a_1.nii.gz
#   t_10983_a_1.nii.gz
#   t_17615_a_1.nii.gz
#   t_5989_a_1.nii.gz
#   t_9158_a_1.nii.gz
#   t_10572_a_1.nii.gz
#   t_4193_a_1.nii.gz
#   t_7701_a_1.nii.gz
#   t_10596_a_1.nii.gz
#   t_10296_b_1.nii.gz
#   t_2344_a_1.nii.gz
#   t_7079_a_1.nii.gz
#   t_12049_a_1.nii.gz
#   t_13381_a_1.nii.gz
#   t_10319_a_1.nii.gz
#   t_18839_a_1.nii.gz
#   t_6581_a_1.nii.gz
#   t_1464_a_1.nii.gz
#   t_19283_a_1.nii.gz
#   t_2187_a_1.nii.gz
#   t_19817_a_1.nii.gz
#   t_13958_a_1.nii.gz
#   t_8549_c_1.nii.gz
#   t_19956_a_1.nii.gz
#   t_7002_a_1.nii.gz
#   t_9055_a_1.nii.gz
#   t_916_a_1.nii.gz
#   t_621_a_1.nii.gz
#   t_18684_a_1.nii.gz
#   t_19450_a_1.nii.gz
#   t_8535_a_1.nii.gz
#   t_6130_b_1.nii.gz
#   t_10310_a_1.nii.gz
#   t_19166_a_1.nii.gz
#   t_19599_a_1.nii.gz
#   t_7667_a_1.nii.gz
#   t_9630_a_1.nii.gz
#   t_1680_a_1.nii.gz
#   t_12136_a_1.nii.gz
#   t_18153_a_1.nii.gz
#   t_9245_a_1.nii.gz
#   t_18791_a_1.nii.gz
#   t_12486_a_1.nii.gz
#   t_15203_a_1.nii.gz
#   t_8030_a_1.nii.gz
#   t_17328_a_1.nii.gz
#   t_2991_a_1.nii.gz
#   t_7841_a_1.nii.gz
#   t_8270_a_1.nii.gz
#   t_9970_a_1.nii.gz
#   t_966_a_1.nii.gz
#   t_14169_a_1.nii.gz
#   t_512_a_1.nii.gz
#   t_11095_a_1.nii.gz
#   t_11669_a_1.nii.gz
#   t_4772_a_1.nii.gz
#   t_7157_a_1.nii.gz
#   t_8871_a_1.nii.gz
#   t_8886_a_1.nii.gz
#   t_10627_a_1.nii.gz
#   t_15651_a_1.nii.gz
#   t_6688_b_1.nii.gz
#   t_992_a_1.nii.gz
#   t_12874_a_1.nii.gz
#   t_3912_a_1.nii.gz
#   t_3144_a_1.nii.gz
#   t_8330_a_1.nii.gz
#   t_727_a_1.nii.gz
#   t_15410_a_1.nii.gz
#   t_10955_a_1.nii.gz
#   t_18978_a_1.nii.gz
#   t_14990_a_1.nii.gz
#   t_14796_a_1.nii.gz
#   t_3918_a_1.nii.gz
#   t_8837_a_1.nii.gz
#   t_17602_a_1.nii.gz
#   t_6960_a_1.nii.gz
#   t_10604_a_1.nii.gz
#   t_18988_a_1.nii.gz
#   t_16825_a_1.nii.gz
#   t_1942_a_1.nii.gz
#   t_16951_b_1.nii.gz
#   t_6443_a_1.nii.gz
#   t_7692_a_1.nii.gz
#   t_15047_a_1.nii.gz
#   t_9579_c_1.nii.gz
#   t_15880_a_1.nii.gz
#   t_14574_a_1.nii.gz
#   t_3641_a_1.nii.gz
#   t_860_a_1.nii.gz
#
# Summary:
# Total files in image folder (modified): 770
# Total files in mask folder: 770
# Files only in image folder: 0
# Files only in mask folder: 0
# Common files: 770

# %%
import os
import shutil

def copy_dataset(source_paths, dest_path):
    """
    Copies files and folders from multiple source paths to a destination path.

    Args:
        source_paths (list): List of source folder paths to copy from.
        dest_path (str): Destination folder path.

    Returns:
        None
    """
    if not os.path.exists(dest_path):
        os.makedirs(dest_path)

    for source in source_paths:
        if not os.path.exists(source):
            print(f"Source path does not exist: {source}")
            continue

        for item in os.listdir(source):
            source_item = os.path.join(source, item)
            dest_item = os.path.join(dest_path, item)

            if os.path.isdir(source_item):
                shutil.copytree(source_item, dest_item, dirs_exist_ok=True)
            else:
                shutil.copy2(source_item, dest_item)

# Define source and destination paths
source_imagesTr = [
    "/data/bruce/unet/Dataset002_AnychestTryAug/imagesTr",
    "/data/bruce/unet/Dataset002_AnychestTry/imagesTr",
]
source_labelsTr = [
    "/data/bruce/unet/Dataset002_AnychestTryAug/labelsTr",
    "/data/bruce/unet/Dataset002_AnychestTry/labelsTr",
]
source_imagesTs = "/data/bruce/unet/Dataset002_AnychestTry/imagesTs"

dest_imagesTr = "/data/bruce/unet/Dataset003_AnychestTry/imagesTr"
dest_labelsTr = "/data/bruce/unet/Dataset003_AnychestTry/labelsTr"
dest_imagesTs = "/data/bruce/unet/Dataset003_AnychestTry/imagesTs"

# Copy datasets
print("Copying imagesTr...")
copy_dataset(source_imagesTr, dest_imagesTr)

print("Copying labelsTr...")
copy_dataset(source_labelsTr, dest_labelsTr)

print("Copying imagesTs...")
copy_dataset([source_imagesTs], dest_imagesTs)

print("Dataset copying completed!")
# Out:
# Copying imagesTr...
# Copying labelsTr...
# Copying imagesTs...
# Dataset copying completed!

# %%
import os
import nibabel as nib
import numpy as np
from skimage.exposure import match_histograms

def histogram_match_nifti(source_path, reference_path, output_path):
    # Load NIfTI files
    source_img = nib.load(source_path)
    reference_img = nib.load(reference_path)
    
    source_data = source_img.get_fdata()
    reference_data = reference_img.get_fdata()
    
   
   
   
   
    
    # Save the matched image
    matched_img = nib.Nifti1Image(matched_data, affine=source_img.affine)
    nib.save(matched_img, output_path)

# Example usage
source_path = "/data/bruce/test/CXR/JPCLN001_0000.nii.gz"  # Path to the source NIfTI file
reference_path = "/data/bruce/test/DRR/t_40_a_1_0000.nii.gz"  # Path to the reference NIfTI file
output_folder = "/data/bruce/test/Histo_trans"  # Path to save the output NIfTI file
output_name = "JPCLN001_0000_hisnew.nii.gz"

os.makedirs(output_folder, exist_ok=True)
output_path = os.path.join(output_folder, output_name)

histogram_match_nifti(source_path, reference_path, output_path)
